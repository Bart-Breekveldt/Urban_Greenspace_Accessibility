# %%
# Import packages
import geopandas as gpd
import numpy as np
import pandas as pd
import libpysal
import networkx as nx
import osmnx as ox
import time
import os
from shapely import geometry
from shapely.geometry import Point, MultiLineString, LineString, Polygon
from shapely.ops import nearest_points
from itertools import product, combinations
import math
import warnings
# Import some libraries
import socket
from wpgpDownload.utils.dl import wpFtp
from wpgpDownload.utils.isos import Countries
from wpgpDownload.utils.convenience_functions import download_country_covariates as dl
from wpgpDownload.utils.wpcsv import Product
import georasters as gr

# %%
# Block 0 cities and assumptions

start = time.time()

cities = ['Philadelphia']

# Assumptions
thresholds = [300, 600, 1000] # route threshold in metres. WHO guideline speaks of access within 300m
walkable_park_dist = 500 # radius in metres
one_park_buffer = 25 # in metres
park_entry_point_buffer = 25 # in metres
min_park_size = 400 # in squared metres (WHO = 0.04 ha = 400m)
park_entry_point_merge = 0 # (default)

grid_block_size = 100 # in meters2 rounded to 100m
nn_iter = 10
#block_combinations = 100
block_network = 250000

# %%
# Block 1 Extract city boundaries, download grids in cities' country

warnings.filterwarnings("ignore")
bound_df = ox.geocoder.geocode_to_gdf(cities)
bound_df.to_file(r'D:/Dumps/City_boundaries/Boundaries_osm.shp')

start_time = time.time()

# Get unique ISO countries, so all country-grids are only loaded once (i.e. Philadelphia, Denver and Washington DC in the USA)
C = pd.DataFrame(Countries)
start_time = time.time()
iso_countries = []
print('required WorldPoP files (execute code string(s) below by country in the Jupyter terminal)')
for i in range(len(cities)): 
    countries = bound_df['display_name'][i].rsplit(',')[-1][1:]
    iso = C[C['name'] == countries].iloc[0,1]
    if iso not in iso_countries:
        iso_countries.append(iso)
        
        # Search for data
        products = Product(iso)
        Results = products.description_contains('people per grid-cell 2020')
        list1 = []
        for p in Results:
            prints = '%s/%s\t%s\t%s' % (p.idx, p.country_name,p.dataset_name,p.path)
            list1.append(prints)
        print('wpgpDownload download -i',iso,'--id',list1[0].split("\t")[0].split('/')[0])

print('')
blocks = []
for i in iso_countries:
    # Get the country by saved path ()
    # You can also use sys.path: path = sys.path[0] +'\\' + str('ISL').lower() + '_ppp_2020.tif'
    # The sys.path is the path Python saves the python file automatically before you
    path = 'D:\\Dumps\\WorldPoP_Grids\\' + i.lower() + '_ppp_2020.tif'
    block = gr.from_file(path)
    blocks.append(block)
    print(i,'extracted', round((time.time() - start_time)/60,2),'mns')
bound_df
# Out:
# required WorldPoP files (execute code string(s) below by country in the Jupyter terminal)
# wpgpDownload download -i USA --id 4983
#
# USA extracted 4.22 mns
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-75.28030 39.97500, -75.28022 39.974...   40.137959   39.867005
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id       lat        lon  \
# 0 -74.955831 -75.280298  282310523  relation  188022  40.00241 -75.139364
#
#                                         display_name     class  \
# 0  Philadelphia, Philadelphia County, Pennsylvani...  boundary
#
#              type  importance
# 0  administrative    0.823797

# %%
# Block 2 population grids extraction
start_time = time.time()
clips = []
grids = []
print(str(grid_block_size) + 'm resolution grids extraction')
for i in range(len(cities)):
    iso = C[bound_df['display_name'][i].rsplit(',')[-1][1:] == C['name']].iloc[0,1]
    contains = [j for j, x in enumerate(iso_countries) if x == iso][0]
    
    # Clip the city from the country
    clipped = blocks[contains].clip(bound_df['geometry'][i])
    clipped = clipped[0].to_geopandas()
    
    # Get dissolvement_key for dissolvement. 
    clipped['row3'] = np.floor(clipped['row']/(grid_block_size/100)).astype(int)
    clipped['col3'] = np.floor(clipped['col']/(grid_block_size/100)).astype(int)
    clipped['dissolve_key'] = clipped['row3'].astype(str) +'-'+ clipped['col3'].astype(str)
    clips.append(clipped)
        
    # Dissolve into block by block grids
    popgrid = clipped[['dissolve_key','geometry','row3','col3']].dissolve('dissolve_key')

    # Get those grids populations and area. Only blocks with population and full blocks
    popgrid['population'] = round(clipped.groupby('dissolve_key')['value'].sum()).astype(int)
    popgrid['area_m'] = round(gpd.GeoSeries(popgrid['geometry'], crs = 4326).to_crs(3043).area).astype(int)
    popgrid = popgrid[popgrid['population'] > 0]
    popgrid = popgrid[popgrid['area_m'] / popgrid['area_m'].max() > 0.95]
    
    # Get centroids and coords
    popgrid['centroid'] = popgrid['geometry'].centroid
    popgrid['centroid_m'] = gpd.GeoSeries(popgrid['centroid'], crs = 4326).to_crs(3043)
    popgrid['grid_lon'] = popgrid['centroid_m'].x
    popgrid['grid_lat'] = popgrid['centroid_m'].y
    popgrid = popgrid.reset_index()
    
    minx = popgrid.bounds['minx']
    maxx = popgrid.bounds['maxx']
    miny = popgrid.bounds['miny']
    maxy = popgrid.bounds['maxy']

    # Some geometries result in a multipolygon when dissolving (like i.e. 0.05 meters) which is in my mind an coords error
    # I therefore create one polygon
    Poly = []
    for k in range(len(popgrid)):
        Poly.append(Polygon([(minx[k],maxy[k]),(maxx[k],maxy[k]),(maxx[k],miny[k]),(minx[k],miny[k])]))
    popgrid['geometry'] = Poly
    
    grids.append(popgrid)
    
    print(cities[i].rsplit(',')[0], round((time.time() - start_time)/60,2),'mns')
    
grids[0]
# Out:
# 100m resolution grids extraction
# Philadelphia 1.04 mns
#       dissolve_key                                           geometry  row3  \
# 0            0-318  POLYGON ((-75.01542 40.13875, -75.01458 40.138...     0
# 1            1-317  POLYGON ((-75.01625 40.13792, -75.01542 40.137...     1
# 2            1-318  POLYGON ((-75.01542 40.13792, -75.01458 40.137...     1
# 3            1-319  POLYGON ((-75.01458 40.13792, -75.01375 40.137...     1
# 4            1-320  POLYGON ((-75.01375 40.13792, -75.01292 40.137...     1
# ...            ...                                                ...   ...
# 34885        99-95  POLYGON ((-75.20125 40.05625, -75.20042 40.056...    99
# 34886        99-96  POLYGON ((-75.20042 40.05625, -75.19958 40.056...    99
# 34887        99-97  POLYGON ((-75.19958 40.05625, -75.19875 40.056...    99
# 34888        99-98  POLYGON ((-75.19875 40.05625, -75.19792 40.056...    99
# 34889        99-99  POLYGON ((-75.19792 40.05625, -75.19708 40.056...    99
#
#        col3  population  area_m                    centroid  \
# 0       318          10   14838  POINT (-75.01500 40.13833)
# 1       317           4   14839  POINT (-75.01583 40.13750)
# 2       318          12   14839  POINT (-75.01500 40.13750)
# 3       319           9   14838  POINT (-75.01417 40.13750)
# 4       320           6   14838  POINT (-75.01333 40.13750)
# ...     ...         ...     ...                         ...
# 34885    95           2   14926  POINT (-75.20083 40.05583)
# 34886    96           4   14926  POINT (-75.20000 40.05583)
# 34887    97           8   14926  POINT (-75.19917 40.05583)
# 34888    98           8   14926  POINT (-75.19833 40.05583)
# 34889    99          20   14926  POINT (-75.19750 40.05583)
#
#                              centroid_m      grid_lon      grid_lat
# 0      POINT (-5675320.992 8459941.626) -5.675321e+06  8.459942e+06
# 1      POINT (-5675486.353 8459999.741) -5.675486e+06  8.460000e+06
# 2      POINT (-5675453.122 8459898.329) -5.675453e+06  8.459898e+06
# 3      POINT (-5675419.890 8459796.917) -5.675420e+06  8.459797e+06
# 4      POINT (-5675386.655 8459695.507) -5.675387e+06  8.459696e+06
# ...                                 ...           ...           ...
# 34885  POINT (-5695801.873 8478348.566) -5.695802e+06  8.478349e+06
# 34886  POINT (-5695768.954 8478246.652) -5.695769e+06  8.478247e+06
# 34887  POINT (-5695736.034 8478144.739) -5.695736e+06  8.478145e+06
# 34888  POINT (-5695703.111 8478042.827) -5.695703e+06  8.478043e+06
# 34889  POINT (-5695670.187 8477940.917) -5.695670e+06  8.477941e+06
#
# [34890 rows x 10 columns]

# %%
# Block 3 Road networks

warnings.filterwarnings("ignore")

start_time = time.time()
graphs = list()
road_nodes = list()
road_edges = list()
road_conn = list()

for i in cities:
    # Get graph, road nodes and edges
    graph = ox.graph_from_place(i, network_type = "all", buffer_dist = (np.max(thresholds)+1000))
    #graphs.append(graph)
    
    road_node, road_edge = ox.graph_to_gdfs(graph)
    
    # Road nodes format
    road_node = road_node.to_crs(4326)
    road_node['geometry_m'] = gpd.GeoSeries(road_node['geometry'], crs = 4326).to_crs(3043)
    road_node['osmid_var'] = road_node.index
    road_node = gpd.GeoDataFrame(road_node, geometry = 'geometry', crs = 4326)
    #road_nodes.append(road_node)
    
    # format road edges
    road_edge = road_edge.to_crs(4326)
    road_edge['geometry_m'] = gpd.GeoSeries(road_edge['geometry'], crs = 4326).to_crs(3043)
    road_edge = road_edge.reset_index()
    road_edge.rename(columns={'u':'from', 'v':'to', 'key':'keys'}, inplace=True)
    road_edge['key'] = road_edge['from'].astype(str) + '-' + road_edge['to'].astype(str)
    #road_edges.append(road_edge)
    
    # Exclude highways and ramps on edges    
    edge_filter = road_edge[(road_edge['highway'].str.contains('motorway') | 
          (road_edge['highway'].str.contains('trunk') & 
           road_edge['maxspeed'].astype(str).str.contains(
               '40 mph|45 mph|50 mph|55 mph|60 mph|65|70|75|80|85|90|95|100|110|120|130|140'))) == False]
    road_edges.append(edge_filter)
    
    # Exclude isolated nodes
    fltrnodes = pd.Series(list(edge_filter['from']) + list(edge_filter['to'])).unique()
    newnodes = road_node[road_node['osmid_var'].isin(fltrnodes)]
    road_nodes.append(newnodes)
    
    # Get only necessary road connections columns for network performance
    road_con = edge_filter[['osmid','key','length','geometry']]
    road_con = road_con.set_index('key')
    road_conn.append(road_con)
    
    # formatting to graph again.
    newnodes = newnodes.loc[:, ~newnodes.columns.isin(['geometry_m', 'osmid_var'])]
    edge_filter = edge_filter.set_index(['from','to','keys'])
    edge_filter = edge_filter.loc[:, ~edge_filter.columns.isin(['geometry_m', 'key'])]
    graph2 = ox.graph_from_gdfs(newnodes, edge_filter)
                            
    graphs.append(graph2)
    print(i.rsplit(',')[0], 'done', round((time.time() - start_time) / 60,2),'mns')
    
road_edges[0]
# Out:
# Philadelphia done 10.98 mns
#               from          to  keys       osmid               name  \
# 0        103237949   103353127     0    11591597  New Jersey Avenue
# 1        103237949   103353090     0    11591597  New Jersey Avenue
# 2        103237949   103237976     0    11580386   Cleveland Avenue
# 3        103237976   103238007     0    11580386   Cleveland Avenue
# 4        103237976   103590312     0    11610261         2nd Street
# ...            ...         ...   ...         ...                ...
# 338097  9726316545  5550941352     0   579660432                NaN
# 338098  9726316545  9726316548     0  1058487388                NaN
# 338099  9726316548  9726316545     0  1058487388                NaN
# 338100  9728655691   110122187     0    12149073  South 10th Street
# 338101  9728655691   110407683     0  1058761471                NaN
#
#             highway  oneway   length  \
# 0       residential   False  111.799
# 1       residential   False  107.489
# 2       residential   False  168.717
# 3       residential   False  151.349
# 4       residential   False  108.508
# ...             ...     ...      ...
# 338097      service   False   39.965
# 338098      service   False   58.733
# 338099      service   False   58.733
# 338100  residential    True    3.250
# 338101      service   False   68.143
#
#                                                  geometry  ref  ... width  \
# 0       LINESTRING (-74.96444 40.03625, -74.96557 40.0...  NaN  ...   NaN
# 1       LINESTRING (-74.96444 40.03625, -74.96337 40.0...  NaN  ...   NaN
# 2       LINESTRING (-74.96444 40.03625, -74.96404 40.0...  NaN  ...   NaN
# 3       LINESTRING (-74.96340 40.03496, -74.96245 40.0...  NaN  ...   NaN
# 4       LINESTRING (-74.96340 40.03496, -74.96448 40.0...  NaN  ...   NaN
# ...                                                   ...  ...  ...   ...
# 338097  LINESTRING (-75.24128 40.06507, -75.24111 40.0...  NaN  ...   NaN
# 338098  LINESTRING (-75.24128 40.06507, -75.24148 40.0...  NaN  ...   NaN
# 338099  LINESTRING (-75.24175 40.06470, -75.24175 40.0...  NaN  ...   NaN
# 338100  LINESTRING (-75.15829 39.94437, -75.15830 39.9...  NaN  ...   NaN
# 338101  LINESTRING (-75.15829 39.94437, -75.15825 39.9...  NaN  ...   NaN
#
#        bridge service tunnel maxspeed access junction area  \
# 0         NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 1         NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 2         NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 3         NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 4         NaN     NaN    NaN      NaN    NaN      NaN  NaN
# ...       ...     ...    ...      ...    ...      ...  ...
# 338097    NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 338098    NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 338099    NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 338100    NaN     NaN    NaN      NaN    NaN      NaN  NaN
# 338101    NaN   alley    NaN      NaN    NaN      NaN  NaN
#
#                                                geometry_m  \
# 0       LINESTRING (-5689489.546 8448457.709, -5689617...
# 1       LINESTRING (-5689489.546 8448457.709, -5689364...
# 2       LINESTRING (-5689489.546 8448457.709, -5689552...
# 3       LINESTRING (-5689653.040 8448263.511, -5689797...
# 4       LINESTRING (-5689653.040 8448263.511, -5689779...
# ...                                                   ...
# 338097  LINESTRING (-5695926.465 8483769.053, -5695935...
# 338098  LINESTRING (-5695926.465 8483769.053, -5695962...
# 338099  LINESTRING (-5696003.982 8483808.258, -5695998...
# 338100  LINESTRING (-5711864.888 8467388.116, -5711869...
# 338101  LINESTRING (-5711864.888 8467388.116, -5711863...
#
#                           key
# 0         103237949-103353127
# 1         103237949-103353090
# 2         103237949-103237976
# 3         103237976-103238007
# 4         103237976-103590312
# ...                       ...
# 338097  9726316545-5550941352
# 338098  9726316545-9726316548
# 338099  9726316548-9726316545
# 338100   9728655691-110122187
# 338101   9728655691-110407683
#
# [336378 rows x 21 columns]

# %%
# Block 4 city greenspace

parks_in_range = list()
for i in range(len(cities)):
    path = 'D:/Dumps/Greenspace/' + cities[i].rsplit(',')[0] + '/' + cities[i].rsplit(',')[0] + '_Greenspace.gpkg'
    greenspace = gpd.read_file(path).to_crs(4326)
    
    warnings.filterwarnings("ignore")

    green_buffer = gpd.GeoDataFrame(geometry = greenspace['geometry'].to_crs(3043).buffer(one_park_buffer).to_crs(4326))
    greenspace['geometry_w_buffer'] = green_buffer
    greenspace['geometry_w_buffer'] = gpd.GeoSeries(greenspace['geometry_w_buffer'], crs = 4326)
    greenspace['geom buffer diff'] = greenspace['geometry_w_buffer'].difference(greenspace['geometry'])

    # This function group components in itself that overlap (with the buffer set of 25 metres)
    # https://stackoverflow.com/questions/68036051/geopandas-self-intersection-grouping
    W = libpysal.weights.fuzzy_contiguity(greenspace['geometry_w_buffer'])
    greenspace['components'] = W.component_labels
    parks = greenspace.dissolve('components')

    # Exclude parks below 0.04 ha.
    parks = parks[parks.to_crs(3043).area > min_park_size]
    
    # Get the park buffer
    
    buffer = gpd.GeoDataFrame(geometry = bound_df.to_crs(3043).buffer(np.max(thresholds)).to_crs(4326), crs = 3043)
    parks_t = parks[parks.intersection(bound_df['geometry'].to_crs(3043).buffer(1000).to_crs(4326)[0]).area > 0]
    parks_t = parks_t.reset_index()
    
    parks_in_range.append(parks_t)
    
parks_in_range[0]
# Out:
#      components                                           geometry  OBJECTID  \
# 0             5  MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...     81288
# 1             6  POLYGON ((-75.24702 39.91695, -75.24706 39.916...     82731
# 2             7  MULTIPOLYGON (((-75.25450 39.95036, -75.25451 ...     82731
# 3             8  POLYGON ((-75.14985 39.96195, -75.14993 39.961...      1260
# 4             9  MULTIPOLYGON (((-75.17212 40.03366, -75.17215 ...      1348
# ..          ...                                                ...       ...
# 468         734  POLYGON ((-75.25746 39.94945, -75.25807 39.949...    242021
# 469         735  POLYGON ((-75.27556 39.96885, -75.27571 39.968...    242022
# 470         736  POLYGON ((-75.25665 39.94613, -75.25671 39.946...    242023
# 471         739  POLYGON ((-75.27769 39.96684, -75.27647 39.966...    242035
# 472         740  POLYGON ((-75.27342 39.96180, -75.27493 39.961...    242038
#
#     FeatClass Category Own_Type Own_Name               Loc_Own Mang_Type  \
# 0         Fee      Fee      LOC     CNTY     Montgomery County       LOC
# 1         Fee      Fee      LOC     CNTY   Philadelphia County       LOC
# 2         Fee      Fee      LOC     CNTY   Philadelphia County       LOC
# 3         Fee      Fee      FED      NPS                   NPS       FED
# 4         Fee      Fee      FED      NPS                   NPS       FED
# ..        ...      ...      ...      ...                   ...       ...
# 468       Fee      Fee      LOC     CITY  Upper Darby Township       LOC
# 469       Fee      Fee      LOC     CITY  Upper Darby Township       LOC
# 470       Fee      Fee      LOC     CITY  Upper Darby Township       LOC
# 471       Fee      Fee      LOC     CITY  UPPER DARBY TOWNSHIP       LOC
# 472       Fee      Fee      LOC     CITY  UPPER DARBY TOWNSHIP       LOC
#
#     Mang_Name  ...      IUCNCtSrc IUCNCtDt Date_Est  \
# 0        CNTY  ...  GAP - Default     2020     1983
# 1        CNTY  ...  GAP - Default     2020     None
# 2        CNTY  ...  GAP - Default     2020     None
# 3         NPS  ...  GAP - Default     2020     1978
# 4         NPS  ...  GAP - Default     2020     None
# ..        ...  ...            ...      ...      ...
# 468      CITY  ...  GAP - Default     2020     None
# 469      CITY  ...  GAP - Default     2020     None
# 470      CITY  ...  GAP - Default     2020     None
# 471      CITY  ...  GAP - Default     2020     None
# 472      CITY  ...  GAP - Default     2020     None
#
#                                    Comments             EsmtHldr EHoldTyp  \
# 0                                      None  Natural Lands Trust      NGO
# 1                                      None                 None     None
# 2                                      None                 None     None
# 3    Edgar Allan Poe National Historic Site                 None     None
# 4     Independence National Historical Park                 None     None
# ..                                      ...                  ...      ...
# 468                                    None                 None     None
# 469                                    None                 None     None
# 470                                    None                 None     None
# 471                                    None                 None     None
# 472                                    None                 None     None
#
#        SHAPE_Leng    SHAPE_Area  \
# 0     2167.370365  1.070843e+05
# 1    36128.050943  3.353065e+06
# 2    36128.050943  3.353065e+06
# 3      216.240707  2.114309e+03
# 4     6162.483495  1.285207e+05
# ..            ...           ...
# 468    217.559826  1.590417e+03
# 469    315.117880  4.314566e+03
# 470    458.291779  1.188739e+04
# 471    552.520121  1.592591e+04
# 472    591.828527  2.070780e+04
#
#                                      geometry_w_buffer  \
# 0    POLYGON ((-75.25609 40.06118, -75.25608 40.061...
# 1    POLYGON ((-75.24691 39.91683, -75.24696 39.916...
# 2    POLYGON ((-75.24828 39.92126, -75.24836 39.921...
# 3    POLYGON ((-75.15037 39.96185, -75.15037 39.961...
# 4    POLYGON ((-75.17280 40.03368, -75.17280 40.033...
# ..                                                 ...
# 468  POLYGON ((-75.25744 39.94930, -75.25744 39.949...
# 469  POLYGON ((-75.27542 39.96896, -75.27542 39.968...
# 470  POLYGON ((-75.25664 39.94598, -75.25669 39.945...
# 471  POLYGON ((-75.27789 39.96684, -75.27789 39.966...
# 472  POLYGON ((-75.27332 39.96168, -75.27333 39.961...
#
#                                       geom buffer diff
# 0    POLYGON ((-75.25608 40.06117, -75.25606 40.061...
# 1    POLYGON ((-75.24696 39.91680, -75.24697 39.916...
# 2    POLYGON ((-75.24836 39.92121, -75.24837 39.921...
# 3    POLYGON ((-75.15037 39.96186, -75.15038 39.961...
# 4    POLYGON ((-75.17280 40.03369, -75.17280 40.033...
# ..                                                 ...
# 468  POLYGON ((-75.25744 39.94930, -75.25806 39.949...
# 469  POLYGON ((-75.27542 39.96896, -75.27541 39.968...
# 470  POLYGON ((-75.25669 39.94597, -75.25671 39.945...
# 471  POLYGON ((-75.27789 39.96685, -75.27788 39.966...
# 472  POLYGON ((-75.27333 39.96167, -75.27335 39.961...
#
# [473 rows x 39 columns]

# %%
# Block 5 park entry points
start_time = time.time()
ParkRoads = list()
for j in range(len(cities)):
    ParkRoad = pd.DataFrame()
    mat = list()
    # For all
    for i in range(len(parks_in_range[j])):
        dist = road_nodes[j]['geometry'].to_crs(3043).distance(parks_in_range[j]['geometry'].to_crs(
            3043)[i])
        buf_nodes = road_nodes[j][(dist < park_entry_point_buffer) & (dist > 0)]
        mat.append(list(np.repeat(i, len(buf_nodes))))
        ParkRoad = pd.concat([ParkRoad, buf_nodes])
        if i % 100 == 0: print(cities[j].rsplit(',')[0], round(i/len(parks_in_range[j])*100,1),'% done', 
                              round((time.time() - start_time) / 60,2),' mns')
    # Park no list conversion
    mat_u = [i for b in map(lambda x:[x] if not isinstance(x, list) else x, mat) for i in b]

    # Format
    ParkRoad['Park_No'] = mat_u
    ParkRoad = ParkRoad.reset_index()
    ParkRoad['park_lon'] = ParkRoad['geometry_m'].x
    ParkRoad['park_lat'] = ParkRoad['geometry_m'].y
    
    # Get the road nodes intersecting with the parks' buffer
    ParkRoad = pd.merge(ParkRoad, parks_in_range[j][['geometry']], left_on = 'Park_No', right_index = True)
    #ParkRoad = pd.merge(ParkRoad, parks_in_range[j][thresholds_str], left_on = 'Park_No', right_index = True)
    
    # Get the walkable park size
    ParkRoad['park_size_walkable'] = ParkRoad['geometry_m'].buffer(walkable_park_dist).to_crs(4326).intersection(ParkRoad['geometry_y'])
    ParkRoad['walk_area'] = ParkRoad['park_size_walkable'].to_crs(3043).area
    ParkRoad['park_area'] = ParkRoad['geometry_y'].to_crs(3043).area
    ParkRoad['share_walked'] = ParkRoad['walk_area'] / ParkRoad['park_area']
    
    # Get size inflation factors for the gravity model
    ParkRoad['size_infl_factor'] = ParkRoad['walk_area'] / ParkRoad['walk_area'].median()
    ParkRoad['size_infl_sqr2'] = ParkRoad['size_infl_factor']**(1/2)
    ParkRoad['size_infl_sqr3'] = ParkRoad['size_infl_factor']**(1/3)
    ParkRoad['size_infl_sqr5'] = ParkRoad['size_infl_factor']**(1/5)
    ParkRoads.append(ParkRoad)
    
    fltr = ParkRoad.loc[:,~ParkRoad.columns.isin(['geometry_x','geometry_m','park_size_walkable', 
                                                          'geometry_m_buffer'])]
                     
    gdf = gpd.GeoDataFrame(pd.DataFrame(fltr), geometry = 'geometry_y', crs = 4326)
    gdf.to_file('D:Dumps/Scores output OSM/Park_entry_points/'+ cities[j] +'.shp')
    
    print(cities[j].rsplit(',')[0],'100 % done', 
                              round((time.time() - start_time) / 60,2),' mns')
    
ParkRoads[0]
# Out:
# Philadelphia 0.0 % done 0.02  mns
# Philadelphia 21.1 % done 1.78  mns
# Philadelphia 42.3 % done 2.56  mns
# Philadelphia 63.4 % done 3.22  mns
# Philadelphia 84.6 % done 3.99  mns
# Philadelphia 100 % done 5.34  mns
#            osmid          y          x  street_count highway  ref  \
# 0      109991185  40.053816 -75.240687             3     NaN  NaN
# 1      109991191  40.054803 -75.239081             3     NaN  NaN
# 2      109991199  40.055776 -75.237501             3     NaN  NaN
# 3      109991204  40.056232 -75.236783             3     NaN  NaN
# 4      110169862  40.063972 -75.249174             3     NaN  NaN
# ...          ...        ...        ...           ...     ...  ...
# 7289  3425873720  39.966878 -75.277524             3     NaN  NaN
# 7290   110006563  39.961942 -75.273003             3     NaN  NaN
# 7291   110133414  39.961600 -75.274141             3     NaN  NaN
# 7292   923789083  39.962719 -75.274196             3     NaN  NaN
# 7293   923789086  39.962481 -75.274715             3     NaN  NaN
#
#                       geometry_x                        geometry_m  \
# 0     POINT (-75.24069 40.05382)  POINT (-5697695.034 8483120.448)
# 1     POINT (-75.23908 40.05480)  POINT (-5697474.612 8482974.522)
# 2     POINT (-75.23750 40.05578)  POINT (-5697257.444 8482831.074)
# 3     POINT (-75.23678 40.05623)  POINT (-5697156.554 8482766.601)
# 4     POINT (-75.24917 40.06397)  POINT (-5696411.964 8484679.155)
# ...                          ...                               ...
# 7289  POINT (-75.27752 39.96688)  POINT (-5713004.185 8483178.234)
# 7290  POINT (-75.27300 39.96194)  POINT (-5713613.274 8482370.035)
# 7291  POINT (-75.27414 39.96160)  POINT (-5713712.736 8482492.281)
# 7292  POINT (-75.27420 39.96272)  POINT (-5713536.406 8482556.428)
# 7293  POINT (-75.27472 39.96248)  POINT (-5713594.849 8482607.942)
#
#        osmid_var  Park_No  ...      park_lat  \
# 0      109991185        0  ...  8.483120e+06
# 1      109991191        0  ...  8.482975e+06
# 2      109991199        0  ...  8.482831e+06
# 3      109991204        0  ...  8.482767e+06
# 4      110169862        0  ...  8.484679e+06
# ...          ...      ...  ...           ...
# 7289  3425873720      471  ...  8.483178e+06
# 7290   110006563      472  ...  8.482370e+06
# 7291   110133414      472  ...  8.482492e+06
# 7292   923789083      472  ...  8.482556e+06
# 7293   923789086      472  ...  8.482608e+06
#
#                                              geometry_y  \
# 0     MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 1     MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 2     MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 3     MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 4     MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# ...                                                 ...
# 7289  POLYGON ((-75.27769 39.96684, -75.27647 39.966...
# 7290  POLYGON ((-75.27342 39.96180, -75.27493 39.961...
# 7291  POLYGON ((-75.27342 39.96180, -75.27493 39.961...
# 7292  POLYGON ((-75.27342 39.96180, -75.27493 39.961...
# 7293  POLYGON ((-75.27342 39.96180, -75.27493 39.961...
#
#                                      park_size_walkable      walk_area  \
# 0     POLYGON ((-75.23914 40.05656, -75.23880 40.056...  198723.068185
# 1     POLYGON ((-75.24278 40.05572, -75.24265 40.055...  291442.444263
# 2     POLYGON ((-75.24077 40.05416, -75.24096 40.054...  245064.061026
# 3     POLYGON ((-75.24005 40.05461, -75.24024 40.054...  187511.352028
# 4     POLYGON ((-75.24676 40.06163, -75.24707 40.061...  194283.946127
# ...                                                 ...            ...
# 7289  POLYGON ((-75.27647 39.96684, -75.27650 39.966...   19734.719624
# 7290  POLYGON ((-75.27493 39.96162, -75.27515 39.961...   47176.323920
# 7291  POLYGON ((-75.27493 39.96162, -75.27515 39.961...   47176.323920
# 7292  POLYGON ((-75.27493 39.96162, -75.27515 39.961...   47176.323920
# 7293  POLYGON ((-75.27493 39.96162, -75.27515 39.961...   47176.323920
#
#          park_area  share_walked  size_infl_factor  size_infl_sqr2  \
# 0     4.192678e+06      0.047398          1.990313        1.410785
# 1     4.192678e+06      0.069512          2.918945        1.708492
# 2     4.192678e+06      0.058450          2.454442        1.566666
# 3     4.192678e+06      0.044724          1.878022        1.370409
# 4     4.192678e+06      0.046339          1.945853        1.394938
# ...            ...           ...               ...             ...
# 7289  1.973472e+04      1.000000          0.197653        0.444582
# 7290  4.717632e+04      1.000000          0.472495        0.687383
# 7291  4.717632e+04      1.000000          0.472495        0.687383
# 7292  4.717632e+04      1.000000          0.472495        0.687383
# 7293  4.717632e+04      1.000000          0.472495        0.687383
#
#       size_infl_sqr3  size_infl_sqr5
# 0           1.257884        1.147583
# 1           1.429142        1.238925
# 2           1.348914        1.196714
# 3           1.233768        1.134332
# 4           1.248447        1.142410
# ...              ...             ...
# 7289        0.582507        0.723071
# 7290        0.778871        0.860755
# 7291        0.778871        0.860755
# 7292        0.778871        0.860755
# 7293        0.778871        0.860755
#
# [7294 rows x 21 columns]

# %%
# Block 5.5 (not in use, buffer is 0, thus retains all the park entry points as is)

# Get buffer of nodes close to each other.
ParkCombs = list([])
for i in range(len(cities)):
    
    # Get the buffer
    ParkComb = ParkRoads[i]
    ParkComb['geometry_m_buffer'] = ParkComb['geometry_m'].buffer(park_entry_point_merge)
    
    # Get and merge components
    M = libpysal.weights.fuzzy_contiguity(ParkComb['geometry_m_buffer'])
    ParkComb['components'] = M.component_labels
    
    # Take centroid of merged components
    centr = gpd.GeoDataFrame(ParkComb, geometry = 'geometry_x', crs = 4326).dissolve('components')['geometry_x'].centroid
    centr = gpd.GeoDataFrame(centr)
    centr.columns = ['comp_centroid']
    
    # Get node closest to the centroid of all merged nodes, which accesses the road network.
    ParkComb = pd.merge(ParkComb, centr, left_on = 'components', right_index = True)
    ParkComb['centr_dist'] = ParkComb['geometry_x'].distance(ParkComb['comp_centroid'])
    ParkComb = ParkComb.iloc[ParkComb.groupby('components')['centr_dist'].idxmin()]
    ParkCombs.append(ParkComb)
ParkCombs[0]
# Out:
#            osmid          y          x  street_count highway  ref  \
# 0      109991185  40.053816 -75.240687             3     NaN  NaN
# 1      109991191  40.054803 -75.239081             3     NaN  NaN
# 2      109991199  40.055776 -75.237501             3     NaN  NaN
# 3      109991204  40.056232 -75.236783             3     NaN  NaN
# 4      110169862  40.063972 -75.249174             3     NaN  NaN
# ...          ...        ...        ...           ...     ...  ...
# 7289  3425873720  39.966878 -75.277524             3     NaN  NaN
# 7290   110006563  39.961942 -75.273003             3     NaN  NaN
# 7291   110133414  39.961600 -75.274141             3     NaN  NaN
# 7292   923789083  39.962719 -75.274196             3     NaN  NaN
# 7293   923789086  39.962481 -75.274715             3     NaN  NaN
#
#                       geometry_x                        geometry_m  \
# 0     POINT (-75.24069 40.05382)  POINT (-5697695.034 8483120.448)
# 1     POINT (-75.23908 40.05480)  POINT (-5697474.612 8482974.522)
# 2     POINT (-75.23750 40.05578)  POINT (-5697257.444 8482831.074)
# 3     POINT (-75.23678 40.05623)  POINT (-5697156.554 8482766.601)
# 4     POINT (-75.24917 40.06397)  POINT (-5696411.964 8484679.155)
# ...                          ...                               ...
# 7289  POINT (-75.27752 39.96688)  POINT (-5713004.185 8483178.234)
# 7290  POINT (-75.27300 39.96194)  POINT (-5713613.274 8482370.035)
# 7291  POINT (-75.27414 39.96160)  POINT (-5713712.736 8482492.281)
# 7292  POINT (-75.27420 39.96272)  POINT (-5713536.406 8482556.428)
# 7293  POINT (-75.27472 39.96248)  POINT (-5713594.849 8482607.942)
#
#        osmid_var  Park_No  ...     park_area  share_walked size_infl_factor  \
# 0      109991185        0  ...  4.192678e+06      0.047398         1.990313
# 1      109991191        0  ...  4.192678e+06      0.069512         2.918945
# 2      109991199        0  ...  4.192678e+06      0.058450         2.454442
# 3      109991204        0  ...  4.192678e+06      0.044724         1.878022
# 4      110169862        0  ...  4.192678e+06      0.046339         1.945853
# ...          ...      ...  ...           ...           ...              ...
# 7289  3425873720      471  ...  1.973472e+04      1.000000         0.197653
# 7290   110006563      472  ...  4.717632e+04      1.000000         0.472495
# 7291   110133414      472  ...  4.717632e+04      1.000000         0.472495
# 7292   923789083      472  ...  4.717632e+04      1.000000         0.472495
# 7293   923789086      472  ...  4.717632e+04      1.000000         0.472495
#
#      size_infl_sqr2  size_infl_sqr3  size_infl_sqr5  geometry_m_buffer  \
# 0          1.410785        1.257884        1.147583      POLYGON EMPTY
# 1          1.708492        1.429142        1.238925      POLYGON EMPTY
# 2          1.566666        1.348914        1.196714      POLYGON EMPTY
# 3          1.370409        1.233768        1.134332      POLYGON EMPTY
# 4          1.394938        1.248447        1.142410      POLYGON EMPTY
# ...             ...             ...             ...                ...
# 7289       0.444582        0.582507        0.723071      POLYGON EMPTY
# 7290       0.687383        0.778871        0.860755      POLYGON EMPTY
# 7291       0.687383        0.778871        0.860755      POLYGON EMPTY
# 7292       0.687383        0.778871        0.860755      POLYGON EMPTY
# 7293       0.687383        0.778871        0.860755      POLYGON EMPTY
#
#       components               comp_centroid  centr_dist
# 0              0  POINT (-75.24069 40.05382)         0.0
# 1              1  POINT (-75.23908 40.05480)         0.0
# 2              2  POINT (-75.23750 40.05578)         0.0
# 3              3  POINT (-75.23678 40.05623)         0.0
# 4              4  POINT (-75.24917 40.06397)         0.0
# ...          ...                         ...         ...
# 7289        7289  POINT (-75.27752 39.96688)         0.0
# 7290        7290  POINT (-75.27300 39.96194)         0.0
# 7291        7291  POINT (-75.27414 39.96160)         0.0
# 7292        7292  POINT (-75.27420 39.96272)         0.0
# 7293        7293  POINT (-75.27472 39.96248)         0.0
#
# [7294 rows x 25 columns]

# %%
# Block 6 grid-parkentry combinations within euclidean threshold distance

start_time = time.time()
RoadComb = list()
for l in range(len(cities)):
    #blockA = block_combinations
    print(cities[l])
    len1 = len(grids[l])
    len2 = len(ParkCombs[l])
    
    # Reduce the size of combinations per iteration
    len4 = 1
    len5 = len1 * len2
    blockC = len5
    while blockC > 10000000:
        blockC = len5 / len4
        #print(blockC, len4)
        len4 = len4+1
        
    # Amount of grids taken per iteration block
    block = round(len1 / len4)
    
    output = pd.DataFrame()
    len_mat = 0
    len_df = 0
    # Checking all the combinations at once is too performance intensive, it is broken down per 1000 (or what you want)
    for i in range(len4):
        # Check all grid-park combinations per block
        l1, l2 = range(i*block,(i+1)*block), range(0,len2)
        listed = pd.DataFrame(list(product(l1, l2)))

        # Merge grid and park information
        grid_merged = pd.merge(listed, 
                               grids[l][['grid_lon','grid_lat','centroid','centroid_m']],
                               left_on = 0, right_index = True)
        node_merged = pd.merge(grid_merged, 
                               ParkCombs[l][['Park_No','osmid','geometry_x','geometry_y','geometry_m','park_lon','park_lat',
                                   'size_infl_sqr2','size_infl_sqr3','size_infl_sqr5','share_walked','park_area','walk_area']], 
                               left_on = 1, right_index = True)

        # Preset index for merging
        node_merged['key'] = range(0,len(node_merged))
        node_merged = node_merged.set_index('key')
        node_merged = node_merged.loc[:, ~node_merged.columns.isin(['index'])]

        # Create lists for better computational performance
        glon = list(node_merged['grid_lon'])
        glat = list(node_merged['grid_lat'])
        plon = list(node_merged['park_lon'])
        plat = list(node_merged['park_lat'])
        infl2 = list(node_merged['size_infl_sqr2'])
        infl3 = list(node_merged['size_infl_sqr3'])
        infl5 = list(node_merged['size_infl_sqr5'])

        # Get the euclidean distances
        mat = list()
        mat2 = list()
        mat3 = list()
        mat4 = list()
        for j in range(len(node_merged)):
            mat.append(math.sqrt(abs(plon[j] - glon[j])**2 + abs(plat[j] - glat[j])**2))
            mat2.append(math.sqrt(abs(plon[j] - glon[j])**2 + abs(plat[j] - glat[j])**2) / infl2[j])
            mat3.append(math.sqrt(abs(plon[j] - glon[j])**2 + abs(plat[j] - glat[j])**2) / infl3[j])
            mat4.append(math.sqrt(abs(plon[j] - glon[j])**2 + abs(plat[j] - glat[j])**2) / infl5[j])

        # Check if distances are within 1000m and join remaining info and concat in master df per 1000.
        mat_df = pd.DataFrame(mat3)[(np.array(mat) <= np.max(thresholds)) | 
                                    (np.array(mat2) <= np.max(thresholds)) | 
                                    (np.array(mat3) <= np.max(thresholds)) | 
                                    (np.array(mat4) <= np.max(thresholds))]

        # join the other gravity euclidean scores and other information
        mat_df = mat_df.join(pd.DataFrame(mat), lsuffix='_infl', rsuffix='_entr', how = 'left')
        mat_df = mat_df.join(pd.DataFrame(mat2), lsuffix='_entry', rsuffix='_pwr', how = 'left')
        mat_df = mat_df.join(pd.DataFrame(mat4), lsuffix='_pwr', rsuffix='_root', how = 'left')
        mat_df.columns = ['size_infl_eucl2','raw euclidean','size_infl_eucl3','size_infl_eucl5']    
        mat_df = mat_df.join(node_merged)

        output = pd.concat([output, mat_df])
        len_mat = len_mat + len(mat_df)
        len_df = len_df + len(node_merged)
            
        if ( (i+1) % 1 == 0) | ((i+1) == len4): 
            print((i+1),'/',len4,'comb. done',round((time.time() - start_time) / 60,2),' mns')
            
            print('of',len_df,'within a Gravity model variant in one of',thresholds,'m threshold:',len_mat)
            len_mat = 0
            len_df = 0
    # Renaming columns
    print('total combinations within distance',len(output))
    
    output.columns = ['size_infl_eucl3','raw euclidean','size_infl_eucl2','size_infl_eucl5',
                      'Grid_No','Park_entry_No','grid_lon','grid_lat','Grid_coords_centroid','Grid_m_centroid',
                      'Park_No','Parkroad_osmid','Park_geom','Parkroad_coords_centroid','Parkroad_m_centroid',
                      'park_lon','park_lat','size_infl_sqr2','size_infl_sqr3','size_infl_sqr5',
                      'parkshare_walked','park_area','walk_area_m2']
    
    output = output[['raw euclidean','size_infl_eucl2','size_infl_eucl3','size_infl_eucl5',
                     'Grid_No','Park_entry_No','Grid_coords_centroid','Grid_m_centroid',
                      'Park_No','Parkroad_osmid','Park_geom','Parkroad_coords_centroid','Parkroad_m_centroid',
                     'walk_area_m2','size_infl_sqr2','size_infl_sqr3','size_infl_sqr5']]
    
    # Reinstate geographic elements
    output = gpd.GeoDataFrame(output, geometry = 'Grid_coords_centroid', crs = 4326)
    output['Grid_m_centroid'] = gpd.GeoSeries(output['Grid_m_centroid'], crs = 3043)
    output['Parkroad_coords_centroid'] = gpd.GeoSeries(output['Parkroad_coords_centroid'], crs = 4326)
    output['Parkroad_m_centroid'] = gpd.GeoSeries(output['Parkroad_m_centroid'], crs = 3043)
    
    # Get the nearest entrance point for the grid centroids
    mat5 = list()
    for i in range(len(output)):
        try:
            nearest = int(road_nodes[l]['geometry'].sindex.nearest(output['Grid_coords_centroid'].iloc[i])[1])
            mat5.append(road_nodes[l]['osmid_var'].iloc[nearest])
        except:
            nearest = int(road_nodes[l]['geometry'].sindex.nearest(output['Grid_coords_centroid'].iloc[i])[1][0])
            mat5.append(road_nodes[l]['osmid_var'].iloc[nearest])
        if i % 250000 == 0: print(round(i/len(output)*100,1),'% gridentry done', round((time.time() - start_time) / 60,2),' mns')
            
    # format resulting dataframe
    output['grid_osm'] = mat5
    output = pd.merge(output, road_nodes[l]['geometry'], left_on = 'grid_osm', right_index = True)
    output['geometry_m'] = gpd.GeoSeries(output['geometry'], crs = 4326).to_crs(3043)
    #output['grid_entry_dist'] = round(gpd.GeoSeries(output['Grid_m_centroid'], crs = 3043
    #                                               ).distance(output['geometry_m']),3)
    output = output.reset_index()
    print('100 % gridentry done', round((time.time() - start_time) / 60,2),' mns')
    RoadComb.append(output)
RoadComb[0]
# Out:
# Philadelphia
# 1 / 27 comb. done 1.5  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 59050
# 2 / 27 comb. done 2.54  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 54750
# 3 / 27 comb. done 3.55  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 72357
# 4 / 27 comb. done 4.56  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 95515
# 5 / 27 comb. done 5.57  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 96850
# 6 / 27 comb. done 6.6  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 84480
# 7 / 27 comb. done 7.6  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 87824
# 8 / 27 comb. done 8.6  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 68256
# 9 / 27 comb. done 9.59  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 58724
# 10 / 27 comb. done 10.58  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 29648
# 11 / 27 comb. done 11.57  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 29097
# 12 / 27 comb. done 12.58  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 47861
# 13 / 27 comb. done 13.57  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 57795
# 14 / 27 comb. done 14.57  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 63095
# 15 / 27 comb. done 15.61  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 73268
# 16 / 27 comb. done 16.63  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 120582
# 17 / 27 comb. done 17.67  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 96014
# 18 / 27 comb. done 18.72  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 41821
# 19 / 27 comb. done 19.73  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 53100
# 20 / 27 comb. done 20.73  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 16102
# 21 / 27 comb. done 21.74  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 26108
# 22 / 27 comb. done 22.74  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 35967
# 23 / 27 comb. done 23.75  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 41847
# 24 / 27 comb. done 24.78  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 36281
# 25 / 27 comb. done 25.84  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 36857
# 26 / 27 comb. done 26.85  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 46178
# 27 / 27 comb. done 27.86  mns
# of 9423848 within a Gravity model variant in one of [300, 600, 1000] m threshold: 64003
# total combinations within distance 1593430
# 0.0 % gridentry done 27.87  mns
# 15.7 % gridentry done 28.26  mns
# 31.4 % gridentry done 28.66  mns
# 47.1 % gridentry done 29.04  mns
# 62.8 % gridentry done 29.4  mns
# 78.4 % gridentry done 29.78  mns
# 94.1 % gridentry done 30.15  mns
# 100 % gridentry done 30.33  mns
#            index  raw euclidean  size_infl_eucl2  size_infl_eucl3  \
# 0            246     588.711176       417.293464       468.017201
# 1            247     489.160666       346.729529       388.875930
# 2            248     393.608019       278.999381       312.912904
# 3            504     557.494365       395.166194       443.200271
# 4           1538     761.539231       445.737656       532.864732
# ...          ...            ...              ...              ...
# 1593425  8594218     928.279618      1211.976137      1108.891321
# 1593426  8595510     970.421527      1266.997261      1159.232615
# 1593427  8600678     956.939067      1249.394353      1143.126925
# 1593428  8601970     906.887108      1184.045747      1083.336554
# 1593429  8960190    1094.931190       997.549531      1029.007614
#
#          size_infl_eucl5  Grid_No  Park_entry_No        Grid_coords_centroid  \
# 0             513.000751      246              0  POINT (-75.24500 40.05500)
# 1             426.252804      247              0  POINT (-75.24417 40.05500)
# 2             342.988579      248              0  POINT (-75.24333 40.05500)
# 3             485.798537      504              0  POINT (-75.24500 40.05417)
# 4             614.677192      246              1  POINT (-75.24500 40.05500)
# ...                  ...      ...            ...                         ...
# 1593425      1032.773097    34718           6651  POINT (-75.14250 40.05583)
# 1593426      1079.658787    34718           6652  POINT (-75.14250 40.05583)
# 1593427      1064.658649    34718           6656  POINT (-75.14250 40.05583)
# 1593428      1008.972501    34718           6657  POINT (-75.14250 40.05583)
# 1593429      1054.886863    33762           6935  POINT (-75.14833 40.05917)
#
#                           Grid_m_centroid  Park_No  ...  \
# 0        POINT (-5697676.322 8483708.862)        0  ...
# 1        POINT (-5697643.511 8483606.888)        0  ...
# 2        POINT (-5697610.697 8483504.915)        0  ...
# 3        POINT (-5697809.025 8483666.164)        0  ...
# 4        POINT (-5697676.322 8483708.862)        0  ...
# ...                                   ...      ...  ...
# 1593425  POINT (-5693492.657 8471217.220)      408  ...
# 1593426  POINT (-5693492.657 8471217.220)      408  ...
# 1593427  POINT (-5693492.657 8471217.220)      408  ...
# 1593428  POINT (-5693492.657 8471217.220)      408  ...
# 1593429  POINT (-5693193.900 8472102.120)      433  ...
#
#                           Park_geom  \
# 0        POINT (-75.24069 40.05382)
# 1        POINT (-75.24069 40.05382)
# 2        POINT (-75.24069 40.05382)
# 3        POINT (-75.24069 40.05382)
# 4        POINT (-75.23908 40.05480)
# ...                             ...
# 1593425  POINT (-75.14622 40.05107)
# 1593426  POINT (-75.14700 40.05118)
# 1593427  POINT (-75.14677 40.05115)
# 1593428  POINT (-75.14574 40.05101)
# 1593429  POINT (-75.15642 40.06123)
#
#                                   Parkroad_coords_centroid  \
# 0        MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 1        MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 2        MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 3        MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# 4        MULTIPOLYGON (((-75.25221 40.05012, -75.25296 ...
# ...                                                    ...
# 1593425  POLYGON ((-75.14640 40.04963, -75.14643 40.049...
# 1593426  POLYGON ((-75.14640 40.04963, -75.14643 40.049...
# 1593427  POLYGON ((-75.14640 40.04963, -75.14643 40.049...
# 1593428  POLYGON ((-75.14640 40.04963, -75.14643 40.049...
# 1593429  POLYGON ((-75.15810 40.05958, -75.15841 40.059...
#
#                       Parkroad_m_centroid   walk_area_m2  size_infl_sqr2  \
# 0        POINT (-5697695.034 8483120.448)  198723.068185        1.410785
# 1        POINT (-5697695.034 8483120.448)  198723.068185        1.410785
# 2        POINT (-5697695.034 8483120.448)  198723.068185        1.410785
# 3        POINT (-5697695.034 8483120.448)  198723.068185        1.410785
# 4        POINT (-5697474.612 8482974.522)  291442.444263        1.708492
# ...                                   ...            ...             ...
# 1593425  POINT (-5694397.065 8471426.383)   58572.853245        0.765922
# 1593426  POINT (-5694412.221 8471527.252)   58572.853245        0.765922
# 1593427  POINT (-5694407.706 8471497.251)   58572.853245        0.765922
# 1593428  POINT (-5694387.566 8471364.129)   58572.853245        0.765922
# 1593429  POINT (-5693185.640 8473197.020)  120290.576012        1.097621
#
#          size_infl_sqr3  size_infl_sqr5    grid_osm  \
# 0              1.257884        1.147583  5550941817
# 1              1.257884        1.147583  5550941817
# 2              1.257884        1.147583  5550941817
# 3              1.257884        1.147583  5550941817
# 4              1.429142        1.238925  5550941817
# ...                 ...             ...         ...
# 1593425        0.837124        0.898822  5546506201
# 1593426        0.837124        0.898822  5546506201
# 1593427        0.837124        0.898822  5546506201
# 1593428        0.837124        0.898822  5546506201
# 1593429        1.064065        1.037961  5545300146
#
#                            geometry                        geometry_m
# 0        POINT (-75.24315 40.05491)  POINT (-5697618.342 8483477.646)
# 1        POINT (-75.24315 40.05491)  POINT (-5697618.342 8483477.646)
# 2        POINT (-75.24315 40.05491)  POINT (-5697618.342 8483477.646)
# 3        POINT (-75.24315 40.05491)  POINT (-5697618.342 8483477.646)
# 4        POINT (-75.24315 40.05491)  POINT (-5697618.342 8483477.646)
# ...                             ...                               ...
# 1593425  POINT (-75.14233 40.05579)  POINT (-5693492.537 8471194.283)
# 1593426  POINT (-75.14233 40.05579)  POINT (-5693492.537 8471194.283)
# 1593427  POINT (-75.14233 40.05579)  POINT (-5693492.537 8471194.283)
# 1593428  POINT (-75.14233 40.05579)  POINT (-5693492.537 8471194.283)
# 1593429  POINT (-75.14842 40.05891)  POINT (-5693237.649 8472099.079)
#
# [1593430 rows x 21 columns]

# %%
# Number of combinations within range per city
for i in range(len(RoadComb)): print(cities[i], len(RoadComb[i]))
# Out:
# Philadelphia 1593430

# %%
# Block 7 calculate route networks of all grid-parkentry combinations within euclidean threshold distance

warnings.filterwarnings("ignore")
start_time = time.time()

Routes = list()
for j in range(len(cities)):
    Graph = graphs[j]
    CityRoads = RoadComb[j] # iloc to test the iteration speed.
    PR = road_nodes[j]
    
    block = block_network

    Route_parts = pd.DataFrame()
    len2 = int(np.ceil(len(CityRoads)/block))
    1217624
    # Divide in chunks of block for computational load
    for k in range(len2):    
        CityRoad = CityRoads.iloc[k*block:k*block+block]

        parknode = list(CityRoad['Parkroad_osmid'])
        gridnode = list(CityRoad['grid_osm'])
        
        s_mat = list([])
        s_mat1 = list([])
        s_mat2 = list([])
        s_mat3 = list([])
        s_mat4 = list([])
        s_mat5 = list([])
        mat_nn = []
        len1 = len(CityRoad)
        
        print(cities[j].rsplit(',')[0], k+1,'/',len2,'range',k*block,'-',k*block+np.where(k*block+block >= len1,len1,block))
        for i in range(len(CityRoad)):
            try:
                shortest = nx.shortest_path(Graph, gridnode[i], parknode[i], 'travel_dist', method = 'dijkstra')
                s_mat.append(shortest)
                shortest_to = list(shortest[1:len(shortest)])
                shortest_to.append(-1)
                s_mat1.append(shortest_to)
                s_mat2.append(list(np.repeat(i+block*k, len(shortest))))
                s_mat3.append(list(np.arange(0, len(shortest))))
                s_mat4.append('normal way')
                s_mat5.append(1)
            except:
                try:
                    # Check the reverse
                    shortest = nx.shortest_path(Graph, parknode[i], gridnode[i], 'travel_dist', method = 'dijkstra')
                    s_mat.append(shortest)
                    shortest_to = list(shortest[1:len(shortest)])
                    shortest_to.append(-1)
                    s_mat1.append(shortest_to)
                    s_mat2.append(list(np.repeat(i+block*k, len(shortest))))
                    s_mat3.append(list(np.arange(0, len(shortest))))
                    s_mat4.append('reverse way')
                    s_mat5.append(0)
                except:
                    # Otherwise the nearest node is taken, which is iterated X times at max, check assumptions, block #0 
                    # Order in route for nearest node:
                    # 1. gridnode to nearest to the original failed parknode
                    # 2. The reverse of 1.
                    # 3. nearest gridnode to the failed one and route to park
                    # 4. The reverse of 3.

                    len3 = 0
                    alt_route = list([])
                    while len3 < nn_iter and len(alt_route) < 1:

                        len3 = len3 +1
                        # Grid nearest
                        g_geom = PR[PR['osmid_var'] == int(CityRoad.iloc[i:i+1]['grid_osm'])]['geometry']
                        g_nearest = pd.DataFrame((abs(float(g_geom.x) - PR['geometry'].x)**2
                        +abs(float(g_geom.y) - PR['geometry'].y)**2)**(1/2)
                                                ).join(PR['osmid_var']).sort_values(0)

                        g_grid = g_nearest.iloc[len3,1]
                        g_park = CityRoad.iloc[i]['Parkroad_osmid']

                        p_geom = PR[PR['osmid_var'] == int(CityRoad.iloc[i:i+1]['Parkroad_osmid'])]['geometry']
                        p_nearest = pd.DataFrame((abs(float(p_geom.x) - PR['geometry'].x)**2
                        +abs(float(p_geom.y) - PR['geometry'].y)**2)**(1/2)
                                                ).join(PR['osmid_var']).sort_values(0)

                        p_grid = CityRoad.iloc[i]['grid_osm']
                        p_park = p_nearest.iloc[len3,1]

                        try:
                            alt_route.append(nx.shortest_path(Graph, p_grid, p_park, 
                                                              'travel_dist', method = 'dijkstra'))
                            s_mat4.append(str(len3)+'grid > n-park')
                            s_mat5.append(1)
                        except:
                            try:
                                alt_route.append(nx.shortest_path(Graph, p_park, p_grid, 
                                                                  'travel_dist', method = 'dijkstra'))
                                s_mat4.append(str(len3)+'n-park > grid')
                                s_mat5.append(0)
                            except:
                                try:
                                    alt_route.append(nx.shortest_path(Graph, g_grid, g_park, 
                                                                      'travel_dist', method = 'dijkstra'))
                                    s_mat4.append(str(len3)+'n-grid > park')
                                    s_mat5.append(1)
                                except:
                                    try:
                                        alt_route.append(nx.shortest_path(Graph, g_grid, g_park, 
                                                                          'travel_dist', method = 'dijkstra'))
                                        s_mat4.append(str(len3)+'park > n-grid')
                                        s_mat5.append(0)
                                    except:
                                        if len3 == nn_iter:
                                            #print(i+block*k,i+block*k,
                                            #      'No route between grid and park-entry and their both 10 alternatives')
                                            pass
                                        pass
                    #print(len(alt_route))
                    if len(alt_route) == 0: 
                        alt = alt_route 
                    else: 
                        alt = alt_route[0]
                    len4 = len(alt)
                    #print(len4)
                    #mat_nn = []
                    if len4 > 0:
                        #print('for index',i+block*k,'nearest node found between', 
                        #                       alt[0],'and',alt[-1])
                        mat_nn.append(i+block*k)
                        s_mat.append(alt)
                        shortest_to = list(alt[1:len(alt)])
                        shortest_to.append(-1)
                        s_mat1.append(shortest_to)
                        s_mat2.append(list(np.repeat(i+block*k,len4)))
                        s_mat3.append(list(np.arange(0, len4)))
                    else:
                        s_mat.append(-1)
                        s_mat1.append(-1)
                        s_mat2.append(i+block*k)
                        s_mat3.append(-1)
                        s_mat4.append('no way')
                        s_mat5.append(2)
                        print(i+block*k,'No route')

            if i % 10000 == 0: print(round((i+block*k)/len(CityRoads)*100,2),'% done',
                                     round((time.time() - start_time) / 60,2),'mns')
        print('for', len(mat_nn),' routes nearest nodes found')

        print(round((i+block*k)/len(CityRoads)*100,2),'% pathfinding done', round((time.time() - start_time) / 60,2),'mns')
                          
        # Unpack lists
        s_mat_u = [i for b in map(lambda x:[x] if not isinstance(x, list) else x, s_mat) for i in b]
        s_mat_u1 = [i for b in map(lambda x:[x] if not isinstance(x, list) else x, s_mat1) for i in b]
        s_mat_u2 = [i for b in map(lambda x:[x] if not isinstance(x, list) else x, s_mat2) for i in b]
        s_mat_u3 = [i for b in map(lambda x:[x] if not isinstance(x, list) else x, s_mat3) for i in b]

        # Format df
        routes = pd.DataFrame([s_mat_u,s_mat_u1,s_mat_u2,s_mat_u3]).transpose()
        routes.columns = ['from','to','route','step']
        mat_key = list([])
        for n in range(len(routes)):
            mat_key.append(str(int(s_mat_u[n])) + '-' + str(int(s_mat_u1[n])))
        routes['key'] = mat_key
        routes = routes.set_index('key')

        # Add route information
        routes = routes.join(road_conn[j], how = 'left')
        routes = gpd.GeoDataFrame(routes, geometry = 'geometry', crs = 4326)
        print('formatting done', round((time.time() - start_time) / 60,2), 'mns')
        routes = routes.sort_values(by = ['route','step'])

        # dissolve route
        routes2 = routes[['route','geometry']].dissolve('route')
        
        # get used grid- and parkosm. Differs at NN-route.
        route_reset = routes.reset_index()
        origin = route_reset['from'].iloc[list(route_reset.groupby('route')['step'].idxmin()),]
        origin = origin.reset_index().iloc[:,-1]
        dest = route_reset['from'].iloc[list(route_reset.groupby('route')['step'].idxmax()),]
        dest = dest.reset_index().iloc[:,-1]
        
        # grid > park = 1, park > grid = 0, no way = 2, detailed way in way_calc.
        routes2['G1-P0'] = s_mat5
        routes2['real_grid'] = np.where(routes2['G1-P0'] == 1, origin, dest)
        routes2['real_park'] = np.where(routes2['G1-P0'] == 1, dest, origin)
        routes2['way_calc.'] = s_mat4
        
        # get route cost, steps, additional information.
        routes2['route_cost'] = routes.groupby('route')['length'].sum()
        routes2['steps'] = routes.groupby('route')['step'].max()
        routes2['index'] = CityRoad.index
        routes2 = routes2.set_index(['index'])
        routes2.index = routes2.index.astype(int)
        routes2 = pd.merge(routes2, CityRoad[['Grid_No','grid_osm','Park_No','Park_entry_No','Parkroad_osmid',
                                              'Grid_m_centroid','walk_area_m2','size_infl_sqr2','size_infl_sqr3',
                                              'size_infl_sqr5','raw euclidean']],
                                                left_index = True, right_index = True)
        routes2 = pd.merge(routes2, road_nodes[j]['geometry_m'], how = 'left', left_on = 'real_grid', right_index = True)
        
        # calculate distance of used road-entry for grid-centroid.
        routes2['real_G-entry'] = round(gpd.GeoSeries(routes2['Grid_m_centroid'], crs = 3043
                                                       ).distance(routes2['geometry_m']),3)
        
        # Calculcate total route cost for the four gravity variants
        routes2['raw_Tcost'] = routes2['route_cost'] + routes2['real_G-entry']
        routes2['grav2_Tcost'] = (routes2['route_cost'] + routes2['real_G-entry']) / routes2['size_infl_sqr2']
        routes2['grav3_Tcost'] = (routes2['route_cost'] + routes2['real_G-entry']) / routes2['size_infl_sqr3']
        routes2['grav5_Tcost'] = (routes2['route_cost'] + routes2['real_G-entry']) / routes2['size_infl_sqr5']

        routes2['gridpark_no'] = routes2['Grid_No'].astype(str) +'-'+ routes2['Park_No'].astype(str)
        print('dissolving done', round((time.time() - start_time) / 60,2), 'mns')
        Route_parts = pd.concat([Route_parts, routes2])
    Routes.append(Route_parts)
Routes[0]
# Out:
# Philadelphia 1 / 7 range 0 - 250000
# 0.0 % done 0.05 mns
# 0.63 % done 0.28 mns
# 1.26 % done 0.44 mns
# 1.88 % done 0.77 mns
# 2.51 % done 0.94 mns
# 3.14 % done 1.08 mns
# 3.77 % done 1.18 mns
# 4.39 % done 1.32 mns
# 5.02 % done 1.54 mns
# 5.65 % done 1.7 mns
# 6.28 % done 1.91 mns
# 6.9 % done 2.14 mns
# 7.53 % done 2.28 mns
# 8.16 % done 2.45 mns
# 8.79 % done 2.97 mns
# 9.41 % done 3.2 mns
# 10.04 % done 3.44 mns
# 10.67 % done 3.66 mns
# 11.3 % done 3.98 mns
# 11.92 % done 4.11 mns
# 12.55 % done 4.4 mns
# 13.18 % done 4.63 mns
# 13.81 % done 4.86 mns
# 14.43 % done 5.16 mns
# 15.06 % done 5.42 mns
# for 165  routes nearest nodes found
# 15.69 % pathfinding done 5.64 mns
# formatting done 7.26 mns
# dissolving done 8.69 mns
# Philadelphia 2 / 7 range 250000 - 500000
# 15.69 % done 8.69 mns
# 16.32 % done 8.94 mns
# 16.94 % done 9.14 mns
# 17.57 % done 9.26 mns
# 18.2 % done 9.39 mns
# 18.83 % done 9.6 mns
# 19.45 % done 9.84 mns
# 20.08 % done 10.11 mns
# 20.71 % done 10.37 mns
# 21.34 % done 10.62 mns
# 21.97 % done 10.88 mns
# 22.59 % done 11.06 mns
# 23.22 % done 11.21 mns
# 23.85 % done 11.31 mns
# 24.48 % done 11.47 mns
# 25.1 % done 11.84 mns
# 25.73 % done 12.32 mns
# 26.36 % done 12.94 mns
# 26.99 % done 13.19 mns
# 27.61 % done 13.36 mns
# 28.24 % done 13.62 mns
# 28.87 % done 13.79 mns
# 29.5 % done 13.95 mns
# 30.12 % done 16.41 mns
# 30.75 % done 17.12 mns
# for 1364  routes nearest nodes found
# 31.38 % pathfinding done 17.52 mns
# formatting done 19.08 mns
# dissolving done 20.45 mns
# Philadelphia 3 / 7 range 500000 - 750000
# 31.38 % done 20.46 mns
# 32.01 % done 20.62 mns
# 32.63 % done 20.79 mns
# 33.26 % done 21.05 mns
# 33.89 % done 21.25 mns
# 34.52 % done 21.36 mns
# 35.14 % done 21.51 mns
# 35.77 % done 21.68 mns
# 36.4 % done 21.84 mns
# 37.03 % done 22.0 mns
# 37.65 % done 22.15 mns
# 38.28 % done 22.33 mns
# 38.91 % done 22.46 mns
# 39.54 % done 22.65 mns
# 40.16 % done 22.86 mns
# 40.79 % done 23.08 mns
# 41.42 % done 23.28 mns
# 42.05 % done 23.45 mns
# 42.68 % done 23.54 mns
# 43.3 % done 23.73 mns
# 43.93 % done 23.87 mns
# 44.56 % done 23.93 mns
# 45.19 % done 24.09 mns
# 45.81 % done 24.21 mns
# 46.44 % done 24.28 mns
# for 6  routes nearest nodes found
# 47.07 % pathfinding done 24.45 mns
# formatting done 25.98 mns
# dissolving done 27.48 mns
# Philadelphia 4 / 7 range 750000 - 1000000
# 47.07 % done 27.49 mns
# 47.7 % done 27.7 mns
# 48.32 % done 27.78 mns
# 48.95 % done 27.93 mns
# 49.58 % done 28.04 mns
# 50.21 % done 28.21 mns
# 50.83 % done 28.46 mns
# 51.46 % done 28.68 mns
# 52.09 % done 28.76 mns
# 52.72 % done 28.87 mns
# 53.34 % done 29.04 mns
# 53.97 % done 29.21 mns
# 54.6 % done 29.63 mns
# 55.23 % done 29.93 mns
# 55.85 % done 30.13 mns
# 56.48 % done 30.25 mns
# 57.11 % done 30.36 mns
# 57.74 % done 30.52 mns
# 58.36 % done 30.69 mns
# 58.99 % done 30.96 mns
# 59.62 % done 31.16 mns
# 60.25 % done 31.48 mns
# 60.87 % done 31.77 mns
# 61.5 % done 31.89 mns
# 62.13 % done 32.02 mns
# for 37  routes nearest nodes found
# 62.76 % pathfinding done 32.18 mns
# formatting done 33.74 mns
# dissolving done 35.16 mns
# Philadelphia 5 / 7 range 1000000 - 1250000
# 62.76 % done 35.16 mns
# 63.39 % done 35.43 mns
# 64.01 % done 35.71 mns
# 64.64 % done 35.95 mns
# 65.27 % done 36.22 mns
# 65.9 % done 36.71 mns
# 66.52 % done 36.97 mns
# 67.15 % done 37.19 mns
# 67.78 % done 37.46 mns
# 68.41 % done 37.67 mns
# 69.03 % done 37.89 mns
# 69.66 % done 38.01 mns
# 70.29 % done 38.2 mns
# 70.92 % done 38.53 mns
# 71.54 % done 38.83 mns
# 72.17 % done 39.15 mns
# 72.8 % done 39.38 mns
# 73.43 % done 39.6 mns
# 74.05 % done 39.76 mns
# 74.68 % done 39.9 mns
# 75.31 % done 40.0 mns
# 75.94 % done 40.27 mns
# 76.56 % done 40.35 mns
# 77.19 % done 40.42 mns
# 77.82 % done 40.55 mns
# for 143  routes nearest nodes found
# 78.45 % pathfinding done 40.95 mns
# formatting done 42.61 mns
# dissolving done 44.16 mns
# Philadelphia 6 / 7 range 1250000 - 1500000
# 78.45 % done 44.17 mns
# 79.07 % done 44.39 mns
# 79.7 % done 44.51 mns
# 80.33 % done 44.59 mns
# 80.96 % done 44.68 mns
# 1297923 No route between grid and park-entry and their both 10 alternatives
# 1298813 No route between grid and park-entry and their both 10 alternatives
# 1298814 No route between grid and park-entry and their both 10 alternatives
# 1298934 No route between grid and park-entry and their both 10 alternatives
# 1298935 No route between grid and park-entry and their both 10 alternatives
# 1298936 No route between grid and park-entry and their both 10 alternatives
# 1298937 No route between grid and park-entry and their both 10 alternatives
# 1298938 No route between grid and park-entry and their both 10 alternatives
# 1298939 No route between grid and park-entry and their both 10 alternatives
# 1298940 No route between grid and park-entry and their both 10 alternatives
# 1298941 No route between grid and park-entry and their both 10 alternatives
# 1298942 No route between grid and park-entry and their both 10 alternatives
# 1298946 No route between grid and park-entry and their both 10 alternatives
# 1298947 No route between grid and park-entry and their both 10 alternatives
# 1298948 No route between grid and park-entry and their both 10 alternatives
# 1298949 No route between grid and park-entry and their both 10 alternatives
# 1298950 No route between grid and park-entry and their both 10 alternatives
# 1298951 No route between grid and park-entry and their both 10 alternatives
# 1298952 No route between grid and park-entry and their both 10 alternatives
# 1298953 No route between grid and park-entry and their both 10 alternatives
# 1298954 No route between grid and park-entry and their both 10 alternatives
# 1299050 No route between grid and park-entry and their both 10 alternatives
# 1299051 No route between grid and park-entry and their both 10 alternatives
# 1299052 No route between grid and park-entry and their both 10 alternatives
# 1299053 No route between grid and park-entry and their both 10 alternatives
# 1299145 No route between grid and park-entry and their both 10 alternatives
# 1299146 No route between grid and park-entry and their both 10 alternatives
# 1299252 No route between grid and park-entry and their both 10 alternatives
# 1299253 No route between grid and park-entry and their both 10 alternatives
# 1299508 No route between grid and park-entry and their both 10 alternatives
# 1299509 No route between grid and park-entry and their both 10 alternatives
# 1299510 No route between grid and park-entry and their both 10 alternatives
# 1299511 No route between grid and park-entry and their both 10 alternatives
# 1299514 No route between grid and park-entry and their both 10 alternatives
# 1299515 No route between grid and park-entry and their both 10 alternatives
# 1299516 No route between grid and park-entry and their both 10 alternatives
# 1299518 No route between grid and park-entry and their both 10 alternatives
# 1299519 No route between grid and park-entry and their both 10 alternatives
# 1299520 No route between grid and park-entry and their both 10 alternatives
# 1299521 No route between grid and park-entry and their both 10 alternatives
# 1299522 No route between grid and park-entry and their both 10 alternatives
# 1299523 No route between grid and park-entry and their both 10 alternatives
# 1299524 No route between grid and park-entry and their both 10 alternatives
# 1299526 No route between grid and park-entry and their both 10 alternatives
# 1299527 No route between grid and park-entry and their both 10 alternatives
# 1299528 No route between grid and park-entry and their both 10 alternatives
# 1299532 No route between grid and park-entry and their both 10 alternatives
# 1299533 No route between grid and park-entry and their both 10 alternatives
# 1299535 No route between grid and park-entry and their both 10 alternatives
# 1299536 No route between grid and park-entry and their both 10 alternatives
# 1299537 No route between grid and park-entry and their both 10 alternatives
# 1299538 No route between grid and park-entry and their both 10 alternatives
# 1299539 No route between grid and park-entry and their both 10 alternatives
# 1299540 No route between grid and park-entry and their both 10 alternatives
# 1299541 No route between grid and park-entry and their both 10 alternatives
# 1299542 No route between grid and park-entry and their both 10 alternatives
# 1299543 No route between grid and park-entry and their both 10 alternatives
# 1299544 No route between grid and park-entry and their both 10 alternatives
# 1299545 No route between grid and park-entry and their both 10 alternatives
# 1299546 No route between grid and park-entry and their both 10 alternatives
# 1299549 No route between grid and park-entry and their both 10 alternatives
# 1299550 No route between grid and park-entry and their both 10 alternatives
# 1299551 No route between grid and park-entry and their both 10 alternatives
# 1299552 No route between grid and park-entry and their both 10 alternatives
# 1299553 No route between grid and park-entry and their both 10 alternatives
# 1299555 No route between grid and park-entry and their both 10 alternatives
# 1299556 No route between grid and park-entry and their both 10 alternatives
# 1299557 No route between grid and park-entry and their both 10 alternatives
# 1299558 No route between grid and park-entry and their both 10 alternatives
# 1299559 No route between grid and park-entry and their both 10 alternatives
# 1299560 No route between grid and park-entry and their both 10 alternatives
# 1299561 No route between grid and park-entry and their both 10 alternatives
# 1299562 No route between grid and park-entry and their both 10 alternatives
# 1299564 No route between grid and park-entry and their both 10 alternatives
# 1299565 No route between grid and park-entry and their both 10 alternatives
# 1299566 No route between grid and park-entry and their both 10 alternatives
# 1299570 No route between grid and park-entry and their both 10 alternatives
# 1299571 No route between grid and park-entry and their both 10 alternatives
# 1299573 No route between grid and park-entry and their both 10 alternatives
# 1299574 No route between grid and park-entry and their both 10 alternatives
# 1299575 No route between grid and park-entry and their both 10 alternatives
# 1299576 No route between grid and park-entry and their both 10 alternatives
# 1299577 No route between grid and park-entry and their both 10 alternatives
# 1299578 No route between grid and park-entry and their both 10 alternatives
# 1299579 No route between grid and park-entry and their both 10 alternatives
# 1299580 No route between grid and park-entry and their both 10 alternatives
# 1299581 No route between grid and park-entry and their both 10 alternatives
# 1299582 No route between grid and park-entry and their both 10 alternatives
# 1299583 No route between grid and park-entry and their both 10 alternatives
# 1299584 No route between grid and park-entry and their both 10 alternatives
# 1299585 No route between grid and park-entry and their both 10 alternatives
# 1299588 No route between grid and park-entry and their both 10 alternatives
# 1299589 No route between grid and park-entry and their both 10 alternatives
# 1299590 No route between grid and park-entry and their both 10 alternatives
# 1299591 No route between grid and park-entry and their both 10 alternatives
# 1299593 No route between grid and park-entry and their both 10 alternatives
# 1299594 No route between grid and park-entry and their both 10 alternatives
# 1299595 No route between grid and park-entry and their both 10 alternatives
# 1299596 No route between grid and park-entry and their both 10 alternatives
# 1299597 No route between grid and park-entry and their both 10 alternatives
# 1299598 No route between grid and park-entry and their both 10 alternatives
# 1299599 No route between grid and park-entry and their both 10 alternatives
# 1299600 No route between grid and park-entry and their both 10 alternatives
# 1299601 No route between grid and park-entry and their both 10 alternatives
# 1299602 No route between grid and park-entry and their both 10 alternatives
# 1299604 No route between grid and park-entry and their both 10 alternatives
# 1299605 No route between grid and park-entry and their both 10 alternatives
# 1299606 No route between grid and park-entry and their both 10 alternatives
# 1299610 No route between grid and park-entry and their both 10 alternatives
# 1299611 No route between grid and park-entry and their both 10 alternatives
# 1299613 No route between grid and park-entry and their both 10 alternatives
# 1299614 No route between grid and park-entry and their both 10 alternatives
# 1299615 No route between grid and park-entry and their both 10 alternatives
# 1299616 No route between grid and park-entry and their both 10 alternatives
# 1299617 No route between grid and park-entry and their both 10 alternatives
# 1299618 No route between grid and park-entry and their both 10 alternatives
# 1299619 No route between grid and park-entry and their both 10 alternatives
# 1299620 No route between grid and park-entry and their both 10 alternatives
# 1299621 No route between grid and park-entry and their both 10 alternatives
# 1299622 No route between grid and park-entry and their both 10 alternatives
# 1299623 No route between grid and park-entry and their both 10 alternatives
# 1299624 No route between grid and park-entry and their both 10 alternatives
# 1299625 No route between grid and park-entry and their both 10 alternatives
# 1299626 No route between grid and park-entry and their both 10 alternatives
# 1299627 No route between grid and park-entry and their both 10 alternatives
# 1299628 No route between grid and park-entry and their both 10 alternatives
# 1299629 No route between grid and park-entry and their both 10 alternatives
# 1299630 No route between grid and park-entry and their both 10 alternatives
# 1299631 No route between grid and park-entry and their both 10 alternatives
# 1299632 No route between grid and park-entry and their both 10 alternatives
# 1299635 No route between grid and park-entry and their both 10 alternatives
# 1299636 No route between grid and park-entry and their both 10 alternatives
# 1299637 No route between grid and park-entry and their both 10 alternatives
# 1299638 No route between grid and park-entry and their both 10 alternatives
# 1299639 No route between grid and park-entry and their both 10 alternatives
# 1299640 No route between grid and park-entry and their both 10 alternatives
# 1299641 No route between grid and park-entry and their both 10 alternatives
# 1299642 No route between grid and park-entry and their both 10 alternatives
# 1299643 No route between grid and park-entry and their both 10 alternatives
# 1299645 No route between grid and park-entry and their both 10 alternatives
# 1299646 No route between grid and park-entry and their both 10 alternatives
# 1299647 No route between grid and park-entry and their both 10 alternatives
# 1299648 No route between grid and park-entry and their both 10 alternatives
# 1299649 No route between grid and park-entry and their both 10 alternatives
# 1299650 No route between grid and park-entry and their both 10 alternatives
# 1299651 No route between grid and park-entry and their both 10 alternatives
# 1299653 No route between grid and park-entry and their both 10 alternatives
# 1299654 No route between grid and park-entry and their both 10 alternatives
# 1299655 No route between grid and park-entry and their both 10 alternatives
# 1299656 No route between grid and park-entry and their both 10 alternatives
# 1299660 No route between grid and park-entry and their both 10 alternatives
# 1299661 No route between grid and park-entry and their both 10 alternatives
# 1299663 No route between grid and park-entry and their both 10 alternatives
# 1299664 No route between grid and park-entry and their both 10 alternatives
# 1299665 No route between grid and park-entry and their both 10 alternatives
# 1299666 No route between grid and park-entry and their both 10 alternatives
# 1299667 No route between grid and park-entry and their both 10 alternatives
# 1299668 No route between grid and park-entry and their both 10 alternatives
# 1299669 No route between grid and park-entry and their both 10 alternatives
# 1299670 No route between grid and park-entry and their both 10 alternatives
# 1299671 No route between grid and park-entry and their both 10 alternatives
# 1299672 No route between grid and park-entry and their both 10 alternatives
# 1299673 No route between grid and park-entry and their both 10 alternatives
# 1299674 No route between grid and park-entry and their both 10 alternatives
# 1299677 No route between grid and park-entry and their both 10 alternatives
# 1299678 No route between grid and park-entry and their both 10 alternatives
# 1299679 No route between grid and park-entry and their both 10 alternatives
# 1299680 No route between grid and park-entry and their both 10 alternatives
# 1299681 No route between grid and park-entry and their both 10 alternatives
# 1299682 No route between grid and park-entry and their both 10 alternatives
# 1299683 No route between grid and park-entry and their both 10 alternatives
# 1299684 No route between grid and park-entry and their both 10 alternatives
# 1299685 No route between grid and park-entry and their both 10 alternatives
# 1299687 No route between grid and park-entry and their both 10 alternatives
# 1299688 No route between grid and park-entry and their both 10 alternatives
# 1299689 No route between grid and park-entry and their both 10 alternatives
# 1299690 No route between grid and park-entry and their both 10 alternatives
# 1299691 No route between grid and park-entry and their both 10 alternatives
# 1299692 No route between grid and park-entry and their both 10 alternatives
# 1299693 No route between grid and park-entry and their both 10 alternatives
# 1299694 No route between grid and park-entry and their both 10 alternatives
# 1299696 No route between grid and park-entry and their both 10 alternatives
# 1299697 No route between grid and park-entry and their both 10 alternatives
# 1299698 No route between grid and park-entry and their both 10 alternatives
# 1299699 No route between grid and park-entry and their both 10 alternatives
# 1299703 No route between grid and park-entry and their both 10 alternatives
# 1299704 No route between grid and park-entry and their both 10 alternatives
# 1299706 No route between grid and park-entry and their both 10 alternatives
# 1299707 No route between grid and park-entry and their both 10 alternatives
# 1299708 No route between grid and park-entry and their both 10 alternatives
# 1299709 No route between grid and park-entry and their both 10 alternatives
# 1299710 No route between grid and park-entry and their both 10 alternatives
# 1299711 No route between grid and park-entry and their both 10 alternatives
# 1299712 No route between grid and park-entry and their both 10 alternatives
# 1299713 No route between grid and park-entry and their both 10 alternatives
# 1299718 No route between grid and park-entry and their both 10 alternatives
# 1299719 No route between grid and park-entry and their both 10 alternatives
# 1299720 No route between grid and park-entry and their both 10 alternatives
# 1299724 No route between grid and park-entry and their both 10 alternatives
# 1299725 No route between grid and park-entry and their both 10 alternatives
# 1299727 No route between grid and park-entry and their both 10 alternatives
# 1299728 No route between grid and park-entry and their both 10 alternatives
# 1299729 No route between grid and park-entry and their both 10 alternatives
# 1299732 No route between grid and park-entry and their both 10 alternatives
# 1299733 No route between grid and park-entry and their both 10 alternatives
# 1299735 No route between grid and park-entry and their both 10 alternatives
# 1299736 No route between grid and park-entry and their both 10 alternatives
# 1299737 No route between grid and park-entry and their both 10 alternatives
# 1299739 No route between grid and park-entry and their both 10 alternatives
# 1299740 No route between grid and park-entry and their both 10 alternatives
# 1299741 No route between grid and park-entry and their both 10 alternatives
# 1299745 No route between grid and park-entry and their both 10 alternatives
# 1299746 No route between grid and park-entry and their both 10 alternatives
# 1299748 No route between grid and park-entry and their both 10 alternatives
# 1299749 No route between grid and park-entry and their both 10 alternatives
# 1299750 No route between grid and park-entry and their both 10 alternatives
# 1299753 No route between grid and park-entry and their both 10 alternatives
# 1299754 No route between grid and park-entry and their both 10 alternatives
# 1299755 No route between grid and park-entry and their both 10 alternatives
# 1299756 No route between grid and park-entry and their both 10 alternatives
# 1299758 No route between grid and park-entry and their both 10 alternatives
# 1299759 No route between grid and park-entry and their both 10 alternatives
# 1299760 No route between grid and park-entry and their both 10 alternatives
# 1299761 No route between grid and park-entry and their both 10 alternatives
# 1299762 No route between grid and park-entry and their both 10 alternatives
# 1299763 No route between grid and park-entry and their both 10 alternatives
# 1299765 No route between grid and park-entry and their both 10 alternatives
# 1299766 No route between grid and park-entry and their both 10 alternatives
# 1299767 No route between grid and park-entry and their both 10 alternatives
# 1299771 No route between grid and park-entry and their both 10 alternatives
# 1299772 No route between grid and park-entry and their both 10 alternatives
# 1299774 No route between grid and park-entry and their both 10 alternatives
# 1299775 No route between grid and park-entry and their both 10 alternatives
# 1299776 No route between grid and park-entry and their both 10 alternatives
# 1299777 No route between grid and park-entry and their both 10 alternatives
# 1299778 No route between grid and park-entry and their both 10 alternatives
# 1299781 No route between grid and park-entry and their both 10 alternatives
# 1299782 No route between grid and park-entry and their both 10 alternatives
# 1299783 No route between grid and park-entry and their both 10 alternatives
# 1299784 No route between grid and park-entry and their both 10 alternatives
# 1299785 No route between grid and park-entry and their both 10 alternatives
# 1299786 No route between grid and park-entry and their both 10 alternatives
# 1299787 No route between grid and park-entry and their both 10 alternatives
# 1299788 No route between grid and park-entry and their both 10 alternatives
# 1299789 No route between grid and park-entry and their both 10 alternatives
# 1299791 No route between grid and park-entry and their both 10 alternatives
# 1299792 No route between grid and park-entry and their both 10 alternatives
# 1299793 No route between grid and park-entry and their both 10 alternatives
# 1299794 No route between grid and park-entry and their both 10 alternatives
# 1299795 No route between grid and park-entry and their both 10 alternatives
# 1299796 No route between grid and park-entry and their both 10 alternatives
# 1299797 No route between grid and park-entry and their both 10 alternatives
# 1299798 No route between grid and park-entry and their both 10 alternatives
# 1299800 No route between grid and park-entry and their both 10 alternatives
# 1299801 No route between grid and park-entry and their both 10 alternatives
# 1299802 No route between grid and park-entry and their both 10 alternatives
# 1299803 No route between grid and park-entry and their both 10 alternatives
# 1299807 No route between grid and park-entry and their both 10 alternatives
# 1299808 No route between grid and park-entry and their both 10 alternatives
# 1299810 No route between grid and park-entry and their both 10 alternatives
# 1299811 No route between grid and park-entry and their both 10 alternatives
# 1299812 No route between grid and park-entry and their both 10 alternatives
# 1299813 No route between grid and park-entry and their both 10 alternatives
# 1299814 No route between grid and park-entry and their both 10 alternatives
# 1299815 No route between grid and park-entry and their both 10 alternatives
# 1299818 No route between grid and park-entry and their both 10 alternatives
# 1299819 No route between grid and park-entry and their both 10 alternatives
# 1299820 No route between grid and park-entry and their both 10 alternatives
# 1299821 No route between grid and park-entry and their both 10 alternatives
# 1299822 No route between grid and park-entry and their both 10 alternatives
# 1299823 No route between grid and park-entry and their both 10 alternatives
# 1299824 No route between grid and park-entry and their both 10 alternatives
# 1299825 No route between grid and park-entry and their both 10 alternatives
# 1299826 No route between grid and park-entry and their both 10 alternatives
# 1299828 No route between grid and park-entry and their both 10 alternatives
# 1299829 No route between grid and park-entry and their both 10 alternatives
# 1299830 No route between grid and park-entry and their both 10 alternatives
# 1299831 No route between grid and park-entry and their both 10 alternatives
# 1299832 No route between grid and park-entry and their both 10 alternatives
# 1299833 No route between grid and park-entry and their both 10 alternatives
# 1299834 No route between grid and park-entry and their both 10 alternatives
# 1299835 No route between grid and park-entry and their both 10 alternatives
# 1299837 No route between grid and park-entry and their both 10 alternatives
# 1299838 No route between grid and park-entry and their both 10 alternatives
# 1299839 No route between grid and park-entry and their both 10 alternatives
# 1299840 No route between grid and park-entry and their both 10 alternatives
# 1299844 No route between grid and park-entry and their both 10 alternatives
# 1299845 No route between grid and park-entry and their both 10 alternatives
# 1299847 No route between grid and park-entry and their both 10 alternatives
# 1299848 No route between grid and park-entry and their both 10 alternatives
# 1299849 No route between grid and park-entry and their both 10 alternatives
# 1299850 No route between grid and park-entry and their both 10 alternatives
# 1299851 No route between grid and park-entry and their both 10 alternatives
# 1299852 No route between grid and park-entry and their both 10 alternatives
# 1299853 No route between grid and park-entry and their both 10 alternatives
# 1299854 No route between grid and park-entry and their both 10 alternatives
# 1299857 No route between grid and park-entry and their both 10 alternatives
# 1299858 No route between grid and park-entry and their both 10 alternatives
# 1299859 No route between grid and park-entry and their both 10 alternatives
# 1299860 No route between grid and park-entry and their both 10 alternatives
# 1299861 No route between grid and park-entry and their both 10 alternatives
# 1299862 No route between grid and park-entry and their both 10 alternatives
# 1299863 No route between grid and park-entry and their both 10 alternatives
# 1299864 No route between grid and park-entry and their both 10 alternatives
# 1299865 No route between grid and park-entry and their both 10 alternatives
# 1299867 No route between grid and park-entry and their both 10 alternatives
# 1299868 No route between grid and park-entry and their both 10 alternatives
# 1299869 No route between grid and park-entry and their both 10 alternatives
# 1299870 No route between grid and park-entry and their both 10 alternatives
# 1299871 No route between grid and park-entry and their both 10 alternatives
# 1299872 No route between grid and park-entry and their both 10 alternatives
# 1299873 No route between grid and park-entry and their both 10 alternatives
# 1299874 No route between grid and park-entry and their both 10 alternatives
# 1299875 No route between grid and park-entry and their both 10 alternatives
# 1299876 No route between grid and park-entry and their both 10 alternatives
# 1299878 No route between grid and park-entry and their both 10 alternatives
# 1299879 No route between grid and park-entry and their both 10 alternatives
# 1299880 No route between grid and park-entry and their both 10 alternatives
# 1299881 No route between grid and park-entry and their both 10 alternatives
# 1299885 No route between grid and park-entry and their both 10 alternatives
# 1299886 No route between grid and park-entry and their both 10 alternatives
# 1299888 No route between grid and park-entry and their both 10 alternatives
# 1299889 No route between grid and park-entry and their both 10 alternatives
# 1299890 No route between grid and park-entry and their both 10 alternatives
# 1299891 No route between grid and park-entry and their both 10 alternatives
# 1299892 No route between grid and park-entry and their both 10 alternatives
# 1299893 No route between grid and park-entry and their both 10 alternatives
# 1299894 No route between grid and park-entry and their both 10 alternatives
# 1299895 No route between grid and park-entry and their both 10 alternatives
# 1299896 No route between grid and park-entry and their both 10 alternatives
# 1299897 No route between grid and park-entry and their both 10 alternatives
# 1299898 No route between grid and park-entry and their both 10 alternatives
# 1299899 No route between grid and park-entry and their both 10 alternatives
# 1299900 No route between grid and park-entry and their both 10 alternatives
# 1299903 No route between grid and park-entry and their both 10 alternatives
# 1299904 No route between grid and park-entry and their both 10 alternatives
# 1299905 No route between grid and park-entry and their both 10 alternatives
# 1299906 No route between grid and park-entry and their both 10 alternatives
# 1299907 No route between grid and park-entry and their both 10 alternatives
# 1299908 No route between grid and park-entry and their both 10 alternatives
# 1299909 No route between grid and park-entry and their both 10 alternatives
# 1299910 No route between grid and park-entry and their both 10 alternatives
# 1299911 No route between grid and park-entry and their both 10 alternatives
# 1299913 No route between grid and park-entry and their both 10 alternatives
# 1299914 No route between grid and park-entry and their both 10 alternatives
# 1299915 No route between grid and park-entry and their both 10 alternatives
# 1299916 No route between grid and park-entry and their both 10 alternatives
# 1299917 No route between grid and park-entry and their both 10 alternatives
# 1299918 No route between grid and park-entry and their both 10 alternatives
# 1299920 No route between grid and park-entry and their both 10 alternatives
# 1299921 No route between grid and park-entry and their both 10 alternatives
# 1299922 No route between grid and park-entry and their both 10 alternatives
# 1299923 No route between grid and park-entry and their both 10 alternatives
# 1299927 No route between grid and park-entry and their both 10 alternatives
# 1299928 No route between grid and park-entry and their both 10 alternatives
# 1299930 No route between grid and park-entry and their both 10 alternatives
# 1299931 No route between grid and park-entry and their both 10 alternatives
# 1299932 No route between grid and park-entry and their both 10 alternatives
# 1299933 No route between grid and park-entry and their both 10 alternatives
# 1299934 No route between grid and park-entry and their both 10 alternatives
# 1299941 No route between grid and park-entry and their both 10 alternatives
# 1299942 No route between grid and park-entry and their both 10 alternatives
# 1299943 No route between grid and park-entry and their both 10 alternatives
# 1299944 No route between grid and park-entry and their both 10 alternatives
# 1299945 No route between grid and park-entry and their both 10 alternatives
# 1299946 No route between grid and park-entry and their both 10 alternatives
# 1299947 No route between grid and park-entry and their both 10 alternatives
# 1299948 No route between grid and park-entry and their both 10 alternatives
# 1299949 No route between grid and park-entry and their both 10 alternatives
# 1299950 No route between grid and park-entry and their both 10 alternatives
# 1299951 No route between grid and park-entry and their both 10 alternatives
# 1299952 No route between grid and park-entry and their both 10 alternatives
# 1299953 No route between grid and park-entry and their both 10 alternatives
# 1299954 No route between grid and park-entry and their both 10 alternatives
# 1299955 No route between grid and park-entry and their both 10 alternatives
# 1299956 No route between grid and park-entry and their both 10 alternatives
# 1299957 No route between grid and park-entry and their both 10 alternatives
# 1299958 No route between grid and park-entry and their both 10 alternatives
# 1299959 No route between grid and park-entry and their both 10 alternatives
# 1299960 No route between grid and park-entry and their both 10 alternatives
# 1299961 No route between grid and park-entry and their both 10 alternatives
# 1299962 No route between grid and park-entry and their both 10 alternatives
# 1299963 No route between grid and park-entry and their both 10 alternatives
# 1299964 No route between grid and park-entry and their both 10 alternatives
# 1299965 No route between grid and park-entry and their both 10 alternatives
# 1299966 No route between grid and park-entry and their both 10 alternatives
# 1299967 No route between grid and park-entry and their both 10 alternatives
# 1299971 No route between grid and park-entry and their both 10 alternatives
# 1299972 No route between grid and park-entry and their both 10 alternatives
# 1299973 No route between grid and park-entry and their both 10 alternatives
# 1299974 No route between grid and park-entry and their both 10 alternatives
# 1299975 No route between grid and park-entry and their both 10 alternatives
# 1299976 No route between grid and park-entry and their both 10 alternatives
# 1299977 No route between grid and park-entry and their both 10 alternatives
# 1299978 No route between grid and park-entry and their both 10 alternatives
# 1299979 No route between grid and park-entry and their both 10 alternatives
# 1299980 No route between grid and park-entry and their both 10 alternatives
# 1299981 No route between grid and park-entry and their both 10 alternatives
# 1299982 No route between grid and park-entry and their both 10 alternatives
# 1299983 No route between grid and park-entry and their both 10 alternatives
# 1299984 No route between grid and park-entry and their both 10 alternatives
# 1299985 No route between grid and park-entry and their both 10 alternatives
# 1299986 No route between grid and park-entry and their both 10 alternatives
# 1299987 No route between grid and park-entry and their both 10 alternatives
# 1299988 No route between grid and park-entry and their both 10 alternatives
# 1299989 No route between grid and park-entry and their both 10 alternatives
# 1299990 No route between grid and park-entry and their both 10 alternatives
# 1299991 No route between grid and park-entry and their both 10 alternatives
# 1299992 No route between grid and park-entry and their both 10 alternatives
# 1299993 No route between grid and park-entry and their both 10 alternatives
# 1299994 No route between grid and park-entry and their both 10 alternatives
# 1299998 No route between grid and park-entry and their both 10 alternatives
# 1299999 No route between grid and park-entry and their both 10 alternatives
# 1300000 No route between grid and park-entry and their both 10 alternatives
# 81.59 % done 58.83 mns
# 1300001 No route between grid and park-entry and their both 10 alternatives
# 1300002 No route between grid and park-entry and their both 10 alternatives
# 1300003 No route between grid and park-entry and their both 10 alternatives
# 1300004 No route between grid and park-entry and their both 10 alternatives
# 1300005 No route between grid and park-entry and their both 10 alternatives
# 1300006 No route between grid and park-entry and their both 10 alternatives
# 1300007 No route between grid and park-entry and their both 10 alternatives
# 1300008 No route between grid and park-entry and their both 10 alternatives
# 1300018 No route between grid and park-entry and their both 10 alternatives
# 1300019 No route between grid and park-entry and their both 10 alternatives
# 1300020 No route between grid and park-entry and their both 10 alternatives
# 1300021 No route between grid and park-entry and their both 10 alternatives
# 1300022 No route between grid and park-entry and their both 10 alternatives
# 1300026 No route between grid and park-entry and their both 10 alternatives
# 1300027 No route between grid and park-entry and their both 10 alternatives
# 1300028 No route between grid and park-entry and their both 10 alternatives
# 1300029 No route between grid and park-entry and their both 10 alternatives
# 1300030 No route between grid and park-entry and their both 10 alternatives
# 1300031 No route between grid and park-entry and their both 10 alternatives
# 1300065 No route between grid and park-entry and their both 10 alternatives
# 1300066 No route between grid and park-entry and their both 10 alternatives
# 1300067 No route between grid and park-entry and their both 10 alternatives
# 1300068 No route between grid and park-entry and their both 10 alternatives
# 1300069 No route between grid and park-entry and their both 10 alternatives
# 1300070 No route between grid and park-entry and their both 10 alternatives
# 1300071 No route between grid and park-entry and their both 10 alternatives
# 1300107 No route between grid and park-entry and their both 10 alternatives
# 1300108 No route between grid and park-entry and their both 10 alternatives
# 1300109 No route between grid and park-entry and their both 10 alternatives
# 1300110 No route between grid and park-entry and their both 10 alternatives
# 1300111 No route between grid and park-entry and their both 10 alternatives
# 1300112 No route between grid and park-entry and their both 10 alternatives
# 1300113 No route between grid and park-entry and their both 10 alternatives
# 1300251 No route between grid and park-entry and their both 10 alternatives
# 1300254 No route between grid and park-entry and their both 10 alternatives
# 1300255 No route between grid and park-entry and their both 10 alternatives
# 1300256 No route between grid and park-entry and their both 10 alternatives
# 1300257 No route between grid and park-entry and their both 10 alternatives
# 1300258 No route between grid and park-entry and their both 10 alternatives
# 1300259 No route between grid and park-entry and their both 10 alternatives
# 1300260 No route between grid and park-entry and their both 10 alternatives
# 1300261 No route between grid and park-entry and their both 10 alternatives
# 1300262 No route between grid and park-entry and their both 10 alternatives
# 1300264 No route between grid and park-entry and their both 10 alternatives
# 1300265 No route between grid and park-entry and their both 10 alternatives
# 1300266 No route between grid and park-entry and their both 10 alternatives
# 1300267 No route between grid and park-entry and their both 10 alternatives
# 1300268 No route between grid and park-entry and their both 10 alternatives
# 1300269 No route between grid and park-entry and their both 10 alternatives
# 1300270 No route between grid and park-entry and their both 10 alternatives
# 1300271 No route between grid and park-entry and their both 10 alternatives
# 1300272 No route between grid and park-entry and their both 10 alternatives
# 1300274 No route between grid and park-entry and their both 10 alternatives
# 1300275 No route between grid and park-entry and their both 10 alternatives
# 1300276 No route between grid and park-entry and their both 10 alternatives
# 1300277 No route between grid and park-entry and their both 10 alternatives
# 1300281 No route between grid and park-entry and their both 10 alternatives
# 1300282 No route between grid and park-entry and their both 10 alternatives
# 1300284 No route between grid and park-entry and their both 10 alternatives
# 1300285 No route between grid and park-entry and their both 10 alternatives
# 1300286 No route between grid and park-entry and their both 10 alternatives
# 1300287 No route between grid and park-entry and their both 10 alternatives
# 1300288 No route between grid and park-entry and their both 10 alternatives
# 1300291 No route between grid and park-entry and their both 10 alternatives
# 1300292 No route between grid and park-entry and their both 10 alternatives
# 1300293 No route between grid and park-entry and their both 10 alternatives
# 1300294 No route between grid and park-entry and their both 10 alternatives
# 1300295 No route between grid and park-entry and their both 10 alternatives
# 1300296 No route between grid and park-entry and their both 10 alternatives
# 1300297 No route between grid and park-entry and their both 10 alternatives
# 1300298 No route between grid and park-entry and their both 10 alternatives
# 1300299 No route between grid and park-entry and their both 10 alternatives
# 1300301 No route between grid and park-entry and their both 10 alternatives
# 1300302 No route between grid and park-entry and their both 10 alternatives
# 1300303 No route between grid and park-entry and their both 10 alternatives
# 1300304 No route between grid and park-entry and their both 10 alternatives
# 1300305 No route between grid and park-entry and their both 10 alternatives
# 1300306 No route between grid and park-entry and their both 10 alternatives
# 1300307 No route between grid and park-entry and their both 10 alternatives
# 1300308 No route between grid and park-entry and their both 10 alternatives
# 1300310 No route between grid and park-entry and their both 10 alternatives
# 1300311 No route between grid and park-entry and their both 10 alternatives
# 1300312 No route between grid and park-entry and their both 10 alternatives
# 1300313 No route between grid and park-entry and their both 10 alternatives
# 1300317 No route between grid and park-entry and their both 10 alternatives
# 1300318 No route between grid and park-entry and their both 10 alternatives
# 1300320 No route between grid and park-entry and their both 10 alternatives
# 1300321 No route between grid and park-entry and their both 10 alternatives
# 1300322 No route between grid and park-entry and their both 10 alternatives
# 1300323 No route between grid and park-entry and their both 10 alternatives
# 1300324 No route between grid and park-entry and their both 10 alternatives
# 1300331 No route between grid and park-entry and their both 10 alternatives
# 1300337 No route between grid and park-entry and their both 10 alternatives
# 1300367 No route between grid and park-entry and their both 10 alternatives
# 1300373 No route between grid and park-entry and their both 10 alternatives
# 1300412 No route between grid and park-entry and their both 10 alternatives
# 1300440 No route between grid and park-entry and their both 10 alternatives
# 1300441 No route between grid and park-entry and their both 10 alternatives
# 1300444 No route between grid and park-entry and their both 10 alternatives
# 1300448 No route between grid and park-entry and their both 10 alternatives
# 1300449 No route between grid and park-entry and their both 10 alternatives
# 1300450 No route between grid and park-entry and their both 10 alternatives
# 1300451 No route between grid and park-entry and their both 10 alternatives
# 1300452 No route between grid and park-entry and their both 10 alternatives
# 1300453 No route between grid and park-entry and their both 10 alternatives
# 1300454 No route between grid and park-entry and their both 10 alternatives
# 1300455 No route between grid and park-entry and their both 10 alternatives
# 1300456 No route between grid and park-entry and their both 10 alternatives
# 1300460 No route between grid and park-entry and their both 10 alternatives
# 1300461 No route between grid and park-entry and their both 10 alternatives
# 1300462 No route between grid and park-entry and their both 10 alternatives
# 1300463 No route between grid and park-entry and their both 10 alternatives
# 1300464 No route between grid and park-entry and their both 10 alternatives
# 1300465 No route between grid and park-entry and their both 10 alternatives
# 1300466 No route between grid and park-entry and their both 10 alternatives
# 1300467 No route between grid and park-entry and their both 10 alternatives
# 1300468 No route between grid and park-entry and their both 10 alternatives
# 1300469 No route between grid and park-entry and their both 10 alternatives
# 1300470 No route between grid and park-entry and their both 10 alternatives
# 1300471 No route between grid and park-entry and their both 10 alternatives
# 1300475 No route between grid and park-entry and their both 10 alternatives
# 1300476 No route between grid and park-entry and their both 10 alternatives
# 1300477 No route between grid and park-entry and their both 10 alternatives
# 1300478 No route between grid and park-entry and their both 10 alternatives
# 1300479 No route between grid and park-entry and their both 10 alternatives
# 1300480 No route between grid and park-entry and their both 10 alternatives
# 1300481 No route between grid and park-entry and their both 10 alternatives
# 1300486 No route between grid and park-entry and their both 10 alternatives
# 1300488 No route between grid and park-entry and their both 10 alternatives
# 1300489 No route between grid and park-entry and their both 10 alternatives
# 1300490 No route between grid and park-entry and their both 10 alternatives
# 1300491 No route between grid and park-entry and their both 10 alternatives
# 1300494 No route between grid and park-entry and their both 10 alternatives
# 1300495 No route between grid and park-entry and their both 10 alternatives
# 1300496 No route between grid and park-entry and their both 10 alternatives
# 1300497 No route between grid and park-entry and their both 10 alternatives
# 1300498 No route between grid and park-entry and their both 10 alternatives
# 1300499 No route between grid and park-entry and their both 10 alternatives
# 1300500 No route between grid and park-entry and their both 10 alternatives
# 1300501 No route between grid and park-entry and their both 10 alternatives
# 1300502 No route between grid and park-entry and their both 10 alternatives
# 1300504 No route between grid and park-entry and their both 10 alternatives
# 1300505 No route between grid and park-entry and their both 10 alternatives
# 1300506 No route between grid and park-entry and their both 10 alternatives
# 1300507 No route between grid and park-entry and their both 10 alternatives
# 1300508 No route between grid and park-entry and their both 10 alternatives
# 1300509 No route between grid and park-entry and their both 10 alternatives
# 1300511 No route between grid and park-entry and their both 10 alternatives
# 1300512 No route between grid and park-entry and their both 10 alternatives
# 1300513 No route between grid and park-entry and their both 10 alternatives
# 1300517 No route between grid and park-entry and their both 10 alternatives
# 1300519 No route between grid and park-entry and their both 10 alternatives
# 1300520 No route between grid and park-entry and their both 10 alternatives
# 1300532 No route between grid and park-entry and their both 10 alternatives
# 1300533 No route between grid and park-entry and their both 10 alternatives
# 1300534 No route between grid and park-entry and their both 10 alternatives
# 1300550 No route between grid and park-entry and their both 10 alternatives
# 1300551 No route between grid and park-entry and their both 10 alternatives
# 1300552 No route between grid and park-entry and their both 10 alternatives
# 1300608 No route between grid and park-entry and their both 10 alternatives
# 1300614 No route between grid and park-entry and their both 10 alternatives
# 1300641 No route between grid and park-entry and their both 10 alternatives
# 1300669 No route between grid and park-entry and their both 10 alternatives
# 1300674 No route between grid and park-entry and their both 10 alternatives
# 1300675 No route between grid and park-entry and their both 10 alternatives
# 1300707 No route between grid and park-entry and their both 10 alternatives
# 1300708 No route between grid and park-entry and their both 10 alternatives
# ...
# 1322144 No route between grid and park-entry and their both 10 alternatives
# 1322145 No route between grid and park-entry and their both 10 alternatives
# 1322146 No route between grid and park-entry and their both 10 alternatives
# 1322147 No route between grid and park-entry and their both 10 alternatives
# 1322148 No route between grid and park-entry and their both 10 alternatives
# 1322149 No route between grid and park-entry and their both 10 alternatives
# 1322150 No route between grid and park-entry and their both 10 alternatives
# 1322151 No route between grid and park-entry and their both 10 alternatives
# 1322152 No route between grid and park-entry and their both 10 alternatives
# 1322153 No route between grid and park-entry and their both 10 alternatives
# 1322154 No route between grid and park-entry and their both 10 alternatives
# 1322155 No route between grid and park-entry and their both 10 alternatives
# 1322156 No route between grid and park-entry and their both 10 alternatives
# 1322157 No route between grid and park-entry and their both 10 alternatives
# 1322158 No route between grid and park-entry and their both 10 alternatives
# 1322159 No route between grid and park-entry and their both 10 alternatives
# 1322160 No route between grid and park-entry and their both 10 alternatives
# 1322161 No route between grid and park-entry and their both 10 alternatives
# 1322162 No route between grid and park-entry and their both 10 alternatives
# 1322165 No route between grid and park-entry and their both 10 alternatives
# 1322166 No route between grid and park-entry and their both 10 alternatives
# 1322167 No route between grid and park-entry and their both 10 alternatives
# 1322168 No route between grid and park-entry and their both 10 alternatives
# 1322169 No route between grid and park-entry and their both 10 alternatives
# 1322170 No route between grid and park-entry and their both 10 alternatives
# 1322171 No route between grid and park-entry and their both 10 alternatives
# 1322172 No route between grid and park-entry and their both 10 alternatives
# 1322173 No route between grid and park-entry and their both 10 alternatives
# 1322175 No route between grid and park-entry and their both 10 alternatives
# 1322176 No route between grid and park-entry and their both 10 alternatives
# 1322177 No route between grid and park-entry and their both 10 alternatives
# 1322178 No route between grid and park-entry and their both 10 alternatives
# 1322179 No route between grid and park-entry and their both 10 alternatives
# 1322180 No route between grid and park-entry and their both 10 alternatives
# 1322181 No route between grid and park-entry and their both 10 alternatives
# 1322182 No route between grid and park-entry and their both 10 alternatives
# 1322183 No route between grid and park-entry and their both 10 alternatives
# 1322184 No route between grid and park-entry and their both 10 alternatives
# 1322185 No route between grid and park-entry and their both 10 alternatives
# 1322186 No route between grid and park-entry and their both 10 alternatives
# 1322188 No route between grid and park-entry and their both 10 alternatives
# 1322189 No route between grid and park-entry and their both 10 alternatives
# 1322190 No route between grid and park-entry and their both 10 alternatives
# 1322191 No route between grid and park-entry and their both 10 alternatives
# 1322195 No route between grid and park-entry and their both 10 alternatives
# 1322196 No route between grid and park-entry and their both 10 alternatives
# 1322198 No route between grid and park-entry and their both 10 alternatives
# 1322199 No route between grid and park-entry and their both 10 alternatives
# 1322200 No route between grid and park-entry and their both 10 alternatives
# 1322201 No route between grid and park-entry and their both 10 alternatives
# 1322202 No route between grid and park-entry and their both 10 alternatives
# 1322203 No route between grid and park-entry and their both 10 alternatives
# 1322204 No route between grid and park-entry and their both 10 alternatives
# 1322205 No route between grid and park-entry and their both 10 alternatives
# 1322206 No route between grid and park-entry and their both 10 alternatives
# 1322207 No route between grid and park-entry and their both 10 alternatives
# 1322208 No route between grid and park-entry and their both 10 alternatives
# 1322209 No route between grid and park-entry and their both 10 alternatives
# 1322210 No route between grid and park-entry and their both 10 alternatives
# 1322211 No route between grid and park-entry and their both 10 alternatives
# 1322212 No route between grid and park-entry and their both 10 alternatives
# 1322213 No route between grid and park-entry and their both 10 alternatives
# 1322214 No route between grid and park-entry and their both 10 alternatives
# 1322215 No route between grid and park-entry and their both 10 alternatives
# 1322216 No route between grid and park-entry and their both 10 alternatives
# 1322226 No route between grid and park-entry and their both 10 alternatives
# 1322228 No route between grid and park-entry and their both 10 alternatives
# 1322229 No route between grid and park-entry and their both 10 alternatives
# 1322230 No route between grid and park-entry and their both 10 alternatives
# 1322283 No route between grid and park-entry and their both 10 alternatives
# 1322332 No route between grid and park-entry and their both 10 alternatives
# 1322334 No route between grid and park-entry and their both 10 alternatives
# 1322335 No route between grid and park-entry and their both 10 alternatives
# 1322384 No route between grid and park-entry and their both 10 alternatives
# 1322422 No route between grid and park-entry and their both 10 alternatives
# 1322428 No route between grid and park-entry and their both 10 alternatives
# 1322462 No route between grid and park-entry and their both 10 alternatives
# 1322468 No route between grid and park-entry and their both 10 alternatives
# 1322510 No route between grid and park-entry and their both 10 alternatives
# 1322547 No route between grid and park-entry and their both 10 alternatives
# 1322553 No route between grid and park-entry and their both 10 alternatives
# 1322590 No route between grid and park-entry and their both 10 alternatives
# 1322596 No route between grid and park-entry and their both 10 alternatives
# 1322640 No route between grid and park-entry and their both 10 alternatives
# 1322677 No route between grid and park-entry and their both 10 alternatives
# 1322683 No route between grid and park-entry and their both 10 alternatives
# 1322726 No route between grid and park-entry and their both 10 alternatives
# 1322727 No route between grid and park-entry and their both 10 alternatives
# 1322728 No route between grid and park-entry and their both 10 alternatives
# 1322744 No route between grid and park-entry and their both 10 alternatives
# 1322745 No route between grid and park-entry and their both 10 alternatives
# 1322746 No route between grid and park-entry and their both 10 alternatives
# 1322846 No route between grid and park-entry and their both 10 alternatives
# 1322890 No route between grid and park-entry and their both 10 alternatives
# 1322927 No route between grid and park-entry and their both 10 alternatives
# 1322933 No route between grid and park-entry and their both 10 alternatives
# 1322978 No route between grid and park-entry and their both 10 alternatives
# 1323044 No route between grid and park-entry and their both 10 alternatives
# 1323045 No route between grid and park-entry and their both 10 alternatives
# 1323046 No route between grid and park-entry and their both 10 alternatives
# 1323047 No route between grid and park-entry and their both 10 alternatives
# 1323190 No route between grid and park-entry and their both 10 alternatives
# 1323232 No route between grid and park-entry and their both 10 alternatives
# 1323272 No route between grid and park-entry and their both 10 alternatives
# 1323310 No route between grid and park-entry and their both 10 alternatives
# 1323316 No route between grid and park-entry and their both 10 alternatives
# 1323354 No route between grid and park-entry and their both 10 alternatives
# 1323408 No route between grid and park-entry and their both 10 alternatives
# 1323409 No route between grid and park-entry and their both 10 alternatives
# 1323410 No route between grid and park-entry and their both 10 alternatives
# 1323411 No route between grid and park-entry and their both 10 alternatives
# 1323412 No route between grid and park-entry and their both 10 alternatives
# 1323413 No route between grid and park-entry and their both 10 alternatives
# 1323414 No route between grid and park-entry and their both 10 alternatives
# 1323450 No route between grid and park-entry and their both 10 alternatives
# 1323648 No route between grid and park-entry and their both 10 alternatives
# 1323649 No route between grid and park-entry and their both 10 alternatives
# 1323721 No route between grid and park-entry and their both 10 alternatives
# 1323722 No route between grid and park-entry and their both 10 alternatives
# 1323723 No route between grid and park-entry and their both 10 alternatives
# 1323724 No route between grid and park-entry and their both 10 alternatives
# 1323745 No route between grid and park-entry and their both 10 alternatives
# 1323746 No route between grid and park-entry and their both 10 alternatives
# 1323747 No route between grid and park-entry and their both 10 alternatives
# 1323748 No route between grid and park-entry and their both 10 alternatives
# 1323864 No route between grid and park-entry and their both 10 alternatives
# 1323897 No route between grid and park-entry and their both 10 alternatives
# 1323932 No route between grid and park-entry and their both 10 alternatives
# 1323969 No route between grid and park-entry and their both 10 alternatives
# 1324001 No route between grid and park-entry and their both 10 alternatives
# 1324039 No route between grid and park-entry and their both 10 alternatives
# 1324069 No route between grid and park-entry and their both 10 alternatives
# 1324070 No route between grid and park-entry and their both 10 alternatives
# 1324347 No route between grid and park-entry and their both 10 alternatives
# 1324450 No route between grid and park-entry and their both 10 alternatives
# 1324473 No route between grid and park-entry and their both 10 alternatives
# 83.47 % done 89.02 mns
# 84.1 % done 89.1 mns
# 84.72 % done 89.27 mns
# 85.35 % done 89.53 mns
# 85.98 % done 89.6 mns
# 86.61 % done 89.78 mns
# 87.23 % done 90.39 mns
# 87.86 % done 90.54 mns
# 88.49 % done 90.63 mns
# 89.12 % done 90.78 mns
# 89.74 % done 92.34 mns
# 90.37 % done 92.49 mns
# 91.0 % done 92.61 mns
# 91.63 % done 93.13 mns
# 92.25 % done 93.33 mns
# 92.88 % done 93.44 mns
# 93.51 % done 93.57 mns
# for 2495  routes nearest nodes found
# 94.14 % pathfinding done 94.07 mns
# formatting done 95.55 mns
# dissolving done 96.99 mns
# Philadelphia 7 / 7 range 1500000 - 1593430
# 94.14 % done 97.0 mns
# 94.76 % done 97.22 mns
# 95.39 % done 97.43 mns
# 96.02 % done 97.52 mns
# 96.65 % done 97.69 mns
# 97.27 % done 97.9 mns
# 97.9 % done 98.21 mns
# 98.53 % done 98.52 mns
# 99.16 % done 98.69 mns
# 99.78 % done 98.79 mns
# for 0  routes nearest nodes found
# 100.0 % pathfinding done 98.9 mns
# formatting done 99.49 mns
# dissolving done 100.02 mns
#                                                   geometry  G1-P0   real_grid  \
# index
# 0        MULTILINESTRING ((-75.24315 40.05491, -75.2427...      1  5550941817
# 1        MULTILINESTRING ((-75.24315 40.05491, -75.2427...      1  5550941817
# 2        MULTILINESTRING ((-75.24315 40.05491, -75.2427...      1  5550941817
# 3        MULTILINESTRING ((-75.24315 40.05491, -75.2427...      1  5550941817
# 4        MULTILINESTRING ((-75.24315 40.05491, -75.2427...      1  5550941817
# ...                                                    ...    ...         ...
# 1593425  MULTILINESTRING ((-75.14233 40.05579, -75.1423...      1  5546506201
# 1593426  MULTILINESTRING ((-75.14233 40.05579, -75.1423...      1  5546506201
# 1593427  MULTILINESTRING ((-75.14233 40.05579, -75.1423...      1  5546506201
# 1593428  MULTILINESTRING ((-75.14233 40.05579, -75.1423...      1  5546506201
# 1593429  MULTILINESTRING ((-75.14842 40.05891, -75.1488...      1  5545300146
#
#           real_park   way_calc.  route_cost  steps  Grid_No    grid_osm  \
# index
# 0         109991185  normal way     303.466      3      246  5550941817
# 1         109991185  normal way     303.466      3      247  5550941817
# 2         109991185  normal way     303.466      3      248  5550941817
# 3         109991185  normal way     303.466      3      504  5550941817
# 4         109991191  normal way     478.764      4      246  5550941817
# ...             ...         ...         ...    ...      ...         ...
# 1593425   109816586  normal way     814.805     15    34718  5546506201
# 1593426   109816593  normal way     881.866     14    34718  5546506201
# 1593427  7205122808  normal way     901.963     15    34718  5546506201
# 1593428  7205122831  normal way     771.033     14    34718  5546506201
# 1593429   109892367  normal way    1101.208     17    33762  5545300146
#
#          Park_No  ...  size_infl_sqr3  size_infl_sqr5 raw euclidean  \
# index             ...
# 0              0  ...        1.257884        1.147583    588.711176
# 1              0  ...        1.257884        1.147583    489.160666
# 2              0  ...        1.257884        1.147583    393.608019
# 3              0  ...        1.257884        1.147583    557.494365
# 4              0  ...        1.429142        1.238925    761.539231
# ...          ...  ...             ...             ...           ...
# 1593425      408  ...        0.837124        0.898822    928.279618
# 1593426      408  ...        0.837124        0.898822    970.421527
# 1593427      408  ...        0.837124        0.898822    956.939067
# 1593428      408  ...        0.837124        0.898822    906.887108
# 1593429      433  ...        1.064065        1.037961   1094.931190
#
#                                geometry_m  real_G-entry  raw_Tcost  \
# index
# 0        POINT (-5697618.342 8483477.646)       238.375    541.841
# 1        POINT (-5697618.342 8483477.646)       131.670    435.136
# 2        POINT (-5697618.342 8483477.646)        28.321    331.787
# 3        POINT (-5697618.342 8483477.646)       268.140    571.606
# 4        POINT (-5697618.342 8483477.646)       238.375    717.139
# ...                                   ...           ...        ...
# 1593425  POINT (-5693492.537 8471194.283)        22.937    837.742
# 1593426  POINT (-5693492.537 8471194.283)        22.937    904.803
# 1593427  POINT (-5693492.537 8471194.283)        22.937    924.900
# 1593428  POINT (-5693492.537 8471194.283)        22.937    793.970
# 1593429  POINT (-5693237.649 8472099.079)        43.855   1145.063
#
#          grav2_Tcost  grav3_Tcost  grav5_Tcost  gridpark_no
# index
# 0         384.070691   430.756063   472.158253        246-0
# 1         308.435471   345.927071   379.175909        247-0
# 2         235.179070   263.766053   289.117970        248-0
# 3         405.168880   454.418824   498.095364        504-0
# 4         419.749691   501.796973   578.839499        246-0
# ...              ...          ...          ...          ...
# 1593425  1093.768831  1000.738155   932.043948    34718-408
# 1593426  1181.324703  1080.846950  1006.653791    34718-408
# 1593427  1207.563655  1104.854144  1029.013046    34718-408
# 1593428  1036.619435   948.449610   883.344673    34718-408
# 1593429  1043.222688  1076.121090  1103.185229    33762-433
#
# [1593430 rows x 25 columns]

# %%
# Block 8 determine best parkentry points from each grid, then calculate grid scores
# and finally aggregate city access in categories (high, medium, low and no access)

start_time = time.time()
popg_acc = pd.DataFrame()
adj_popg_acc = pd.DataFrame()
grid_scores = list([])
gridpark = list([])
for n in range(len(cities)):    
    print(cities[n])
    
    # For the four distance decay variants regarding park size.
    l1 = list(['raw','grav2','grav3','grav5'])
    m1 = list(['entrance','gravity**(1/2)','gravity**(1/3)','gravity**(1/5)'])
    grid_score = list([])
    gridparks = list([])
    gridpark.append(gridparks)
    popgrid_access = pd.DataFrame()
    adj_popgrid_access = pd.DataFrame()
    for i in range(len(l1)):
        # Get the lowest indices grouped by a key consisting of grid no and park no (best entry point from a grid to a park)
        Rclean = Routes[n][Routes[n]['way_calc.'] != 'no way'].reset_index()
        str1 = 'gridpark_' + l1[i]
        locals()[str1] = Rclean.iloc[Rclean.groupby('gridpark_no')[(str(l1[i]) +'_Tcost')].idxmin()]
        l2 = list()
        
        # Get the total cost column
        for j in enumerate(l1): 
            if j[0] != i: l2.append(j[1] + '_Tcost')
        locals()[str1] = locals()[str1].loc[:, ~locals()[str1].columns.isin(l2)]
        
        # Get grid information
        locals()[str1] = pd.merge(locals()[str1], grids[n][['population','geometry']],
                                left_on = 'Grid_No', right_index = True, how = 'outer')
        locals()[str1] = locals()[str1].reset_index()
        
        # formatting
        locals()[str1]['Park_No'] = locals()[str1]['Park_No'].fillna(-1)
        locals()[str1]['Park_No'] = locals()[str1]['Park_No'].astype(int)
        locals()[str1]['Park_entry_No'] = locals()[str1]['Park_entry_No'].fillna(-1)
        locals()[str1]['Park_entry_No'] = locals()[str1]['Park_entry_No'].astype(int)
        
        grdsc = pd.DataFrame()
        gridsc = pd.DataFrame()
        print(m1[i], round((time.time() - start_time) / 60,2), 'mns')
        
        # For each threshold given, calculate a score
        for k in range(len(thresholds)):
            t = thresholds[k]
            str2 = str(t)
            score = 'tr_'+ str2
            adj_score = 'adj_tr_' + str2
            
            #Only get routes within the threshold given (it loops over every threshold) and calculate the scores
            thold = locals()[str1][locals()[str1][l1[i] + '_Tcost'] <= t]
            thold[score] = t - thold[l1[i] + '_Tcost']
            thold['pop' + score] = thold[score] * thold['population']
            thold[adj_score] = thold[score] * ((math.pi*600**2) / (math.pi*t**2)) / (600/t)
            thold['walk_area_ha' + str2] = locals()[str1]['walk_area_m2'] /10000
            thold['walkha_person' + str2] = thold['population'] / thold['walk_area_ha' + str2]
            
            # Join the gridpark information from before.
            locals()[str1] = locals()[str1].join(thold[[score,'pop' + score,adj_score,'walk_area_ha' + str2, 'walkha_person' + str2]])
            # get the grid_scores
            gs = pd.DataFrame()
            gs[[score,'pop_' + score,adj_score,'walkha_' + str2]] = locals()[str1].groupby(
                    'Grid_No')[score,'pop' + score, adj_score, 'walk_area_ha' + str2].sum()
            
            gs['walkha_person_' + score] = locals()[str1].groupby('Grid_No')['walkha_person' + str2].mean()

            trstr = locals()[str1][locals()[str1][score] > 0]
            gs[score + '_parks'] = trstr.groupby('Grid_No')['gridpark_no'].count()
            
            # Add the routes as a dissolved line_geom
            gs[score + '_routes'] = gpd.GeoDataFrame(trstr[['Grid_No','geometry_x']],
                                                          geometry = 'geometry_x', crs = 4326).dissolve('Grid_No')

            # Add parks which grids have access to with its closest access point
            gs[score+'Park:entry'] = trstr[trstr['Park_No'] >=0].groupby('Grid_No')['Park_No'].apply(list).astype(str
            ) + ':' + trstr[trstr['Park_entry_No'] >=0].groupby('Grid_No')['Park_entry_No'].apply(list).astype(str)
            
            # determine the thresholds category-score. 
            # High >= threshold (perfect score to one park), medium is above half perfect, 
            # low is below this and no is no access to a park for a certain grid within the threshold given
            gs[score+'_access'] = np.select([gs[score] >= t, (gs[score] < t) & (
            gs[score]>= t/2), (gs[score] < t/2) & (gs[score]> 0), gs[score] <= 0],
                  ['1 high','2 medium','3 low','4 no'])
                        
            gs[score+'_adj_access'] = np.select([gs[adj_score] >= t, (gs[adj_score] < t) & (
            gs[adj_score]>= t/2), (gs[adj_score] < t/2) & (gs[adj_score]> 0), gs[adj_score] <= 0],
                  ['1 high','2 medium','3 low','4 no'])
            
            gs = gs.join(grids[n]['population'], how = 'outer')
            grdsc = pd.concat([grdsc, gs], axis = 1)
            
            gs = gpd.GeoDataFrame(gs, geometry = score + '_routes', crs = 4326)
            
            if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_lines/'):
                os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_lines/')
                
            gs.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_lines/gridscore_'+ l1[i] + '_' + str2 + '_' + cities[n] + '.shp')
            
            gsc = gs.loc[:,~gs.columns.isin([score + '_routes'])]
            gridsc = pd.concat([gridsc, gsc])

            # Group according to the categories just created and sum the populations living in those grids
            popgacc = pd.DataFrame()
            popgacc[m1[i]+'_'+str(t)] = gs.groupby(score+'_access')['population'].sum()
            popgrid_access = pd.concat([popgrid_access, popgacc],axis=1)   
            
            adj_popgacc = pd.DataFrame()
            adj_popgacc[m1[i]+'_'+str(t)] = gs.groupby(score+'_adj_access')['population'].sum()
            adj_popgrid_access = pd.concat([adj_popgrid_access, adj_popgacc],axis=1)   
            print('grid ',t)
        
        grid_score.append(grdsc)
        
        gridsc = gridsc.join(grids[n]['geometry'])
        gridsc = gpd.GeoDataFrame(gridsc, geometry = 'geometry', crs = 4326)
        
        if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_geoms/'):
            os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_geoms/')
            
        gridsc.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_geoms/gridscore_'+ l1[i] + '_' + cities[n] + '.shp')
        
        # Detailed scores to files number of cities * ways to measure = number of files.
        # Different threshold-scores are in the same dataframe
        gridsc = gridsc.loc[:, gridsc.columns!='geometry']
        
        if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_csv/'):
            os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_csv/')
        
        gridsc.to_csv('D:/Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_csv/gridscore_'+ l1[i] + '_' + cities[n] + '.csv')
        gridparks.append(locals()[str1])
        
    grid_scores.append(grid_score)

    # For each city, divide the population access by group by the total to get its share.
    popgrid_access = popgrid_access / popgrid_access.sum()
    popgrid_access = pd.DataFrame(popgrid_access.unstack())
    popg_acc = pd.concat([popg_acc, popgrid_access], axis = 1)
    
    adj_popgrid_access = adj_popgrid_access / adj_popgrid_access.sum()
    adj_popgrid_access = pd.DataFrame(adj_popgrid_access.unstack())
    adj_popg_acc = pd.concat([adj_popg_acc, adj_popgrid_access], axis = 1)
    
    print(cities[n],'done', round((time.time() - start_time) / 60,2), 'mns')
popg_acc.columns = cities
adj_popg_acc.columns = cities

popg_acc.to_csv('D:/Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/popgrid_access.csv')
adj_popg_acc.to_csv('D:/Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/radius-euclidean adjusted popgrid access.csv')

popg_acc
# Out:
# Philadelphia
# entrance 0.14 mns
# grid  300
# grid  600
# grid  1000
# gravity**(1/2) 2.8 mns
# grid  300
# grid  600
# grid  1000
# gravity**(1/3) 5.45 mns
# grid  300
# grid  600
# grid  1000
# gravity**(1/5) 7.27 mns
# grid  300
# grid  600
# grid  1000
# Philadelphia done 8.95 mns
#                               Philadelphia
# entrance_300        1 high        0.010640
#                     2 medium      0.135305
#                     3 low         0.221468
#                     4 no          0.632587
# entrance_600        1 high        0.131396
#                     2 medium      0.316830
#                     3 low         0.323869
#                     4 no          0.227905
# entrance_1000       1 high        0.492725
#                     2 medium      0.305238
#                     3 low         0.138870
#                     4 no          0.063167
# gravity**(1/2)_300  1 high        0.002397
#                     2 medium      0.120023
#                     3 low         0.174741
#                     4 no          0.702838
# gravity**(1/2)_600  1 high        0.037573
#                     2 medium      0.289219
#                     3 low         0.325834
#                     4 no          0.347374
# gravity**(1/2)_1000 1 high        0.234345
#                     2 medium      0.419841
#                     3 low         0.239585
#                     4 no          0.106230
# gravity**(1/3)_300  1 high        0.003063
#                     2 medium      0.116408
#                     3 low         0.178751
#                     4 no          0.701778
# gravity**(1/3)_600  1 high        0.042823
#                     2 medium      0.287131
#                     3 low         0.333182
#                     4 no          0.336864
# gravity**(1/3)_1000 1 high        0.255266
#                     2 medium      0.416491
#                     3 low         0.238278
#                     4 no          0.089965
# gravity**(1/5)_300  1 high        0.004124
#                     2 medium      0.117990
#                     3 low         0.189132
#                     4 no          0.688754
# gravity**(1/5)_600  1 high        0.056813
#                     2 medium      0.296946
#                     3 low         0.339163
#                     4 no          0.307079
# gravity**(1/5)_1000 1 high        0.319903
#                     2 medium      0.393705
#                     3 low         0.211442
#                     4 no          0.074950

# %%
# Block 9 calculte park scores from previously determined best grid-park routes.

start_time = time.time()
cityparks = list([])
for i in range(len(cities)):
    
    # For the four distance decay variants regarding park size.
    l1 = list(['raw','grav2','grav3','grav5'])
    m1 = list(['entrance','gravity**(1/2)','gravity**(1/3)','gravity**(1/5)'])
    parks = list([])
    for j in range(len(l1)):
        parksc = pd.DataFrame()
        prksc = pd.DataFrame()
        for k in range(len(thresholds)):
            score = 'tr_' + str(thresholds[k])
            str2 = str(thresholds[k])
            str1 = gridpark[i][j][gridpark[i][j][score] > 0]

            # Get the park scores
            prk = pd.DataFrame()
            prk[[score,'pop_' + score,'popreach'+score]] = str1.groupby('Park_No')[score,'pop' + score,'population'].sum()
            
            prk['walkha_person_' + score] = str1.groupby('Park_No')['walkha_person' + str2].mean()
            prk[score + '_parks'] = str1.groupby('Park_No')['gridpark_no'].count()
            
            # Add the routes as a dissolved line_geom
            prk[score+'route'] = gpd.GeoDataFrame(str1[['Park_No','geometry_x']], 
                             geometry = 'geometry_x', crs = 4326).dissolve('Park_No')
            
            # Add parks which grids have access to with its closest access point
            prk[score+'Grid:Pentry'] = str1[str1['Grid_No'] >=0].groupby('Park_No')['Grid_No'].apply(list).astype(str
            ) + ':' + str1[str1['Park_entry_No'] >=0].groupby('Park_No')['Park_entry_No'].apply(list).astype(str)
            
            # Get all parks, even with no score.
            prk = prk.join(parks_in_range[i].iloc[:,0], how = 'outer')
            prk = prk.loc[:,~prk.columns.isin(['components'])]
            print('park', thresholds[k])
            
            # Get the park score categories (same as grid score)
            prk[score+'_access'] = np.select([prk[score] >= t, (prk[score] < t) & (
                prk[score]>= t/2), (prk[score] < t/2) & (prk[score]> 0), prk[score] <= 0 | prk[score].isna()],
                ['1 high','2 medium','3 low','4 no'])

            parksc = pd.concat([parksc, prk], axis = 1)
                
            prk = gpd.GeoDataFrame(prk, geometry = score+'route', crs = 4326)
        
            if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_lines/'):
                os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_lines/')
            
            prk.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_lines/parkscore_'+ l1[j] + '_' + str2 + '_' + cities[i] + '.shp')
            
            psc = prk.loc[:,~prk.columns.isin([score + 'route'])]
            prksc = pd.concat([prksc, psc])
            
        parks.append(parksc)
        
        prksc = prksc.join(parks_in_range[i]['geometry'])
        prksc = gpd.GeoDataFrame(prksc, geometry = 'geometry', crs = 4326)
        
        if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_geoms/'):
            os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_geoms/')
            
        prksc.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_geoms/parkscore_'+ l1[j] + '_' + cities[i] + '.shp')
        
        # Detailed scores to files number of cities * ways to measure = number of files.
        # Different threshold-scores are in the same dataframe
        prksc = prksc.loc[:, prksc.columns!='geometry']
        
        if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_csv/'):
            os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_csv/')
            
        prksc.to_csv('D:/Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Park_csv/parkscore_'+ l1[j] + '_' + cities[i]+ '.csv')

        print(m1[j], round((time.time() - start_time) / 60,2), 'mns')
    cityparks.append(parks)
    print(cities[i],'done', round((time.time() - start_time) / 60,2), 'mns')
pd.DataFrame(cityparks[0][0])
# Out:
# park 300
# park 600
# park 1000
# entrance 1.09 mns
# park 300
# park 600
# park 1000
# gravity**(1/2) 2.73 mns
# park 300
# park 600
# park 1000
# gravity**(1/3) 3.7 mns
# park 300
# park 600
# park 1000
# gravity**(1/5) 4.5 mns
# Philadelphia done 4.5 mns
#         tr_300   pop_tr_300  popreachtr_300  walkha_person_tr_300  \
# 0     9768.904   105926.259           842.0              0.510050
# 1     1316.272    32149.626           289.0              5.511059
# 2    45973.226  1867679.053         16187.0              1.898805
# 3     1613.461   107356.147           558.0            115.975062
# 4     1526.436    12887.018           177.0             11.826702
# ..         ...          ...             ...                   ...
# 468        NaN          NaN             NaN                   NaN
# 469        NaN          NaN             NaN                   NaN
# 470        NaN          NaN             NaN                   NaN
# 471        NaN          NaN             NaN                   NaN
# 472        NaN          NaN             NaN                   NaN
#
#      tr_300_parks                                        tr_300route  \
# 0            76.0  (LINESTRING (-75.239456 40.052769, -75.240065 ...
# 1            12.0  (LINESTRING (-75.2459535 39.9198435, -75.24618...
# 2           357.0  (LINESTRING (-75.2586879 39.9851592, -75.25859...
# 3            10.0  (LINESTRING (-75.151487 39.963505, -75.151726 ...
# 4            14.0  (LINESTRING (-75.1747348 40.0358392, -75.17395...
# ..            ...                                                ...
# 468           NaN                                                NaN
# 469           NaN                                                NaN
# 470           NaN                                                NaN
# 471           NaN                                                NaN
# 472           NaN                                                NaN
#
#                                      tr_300Grid:Pentry tr_300_access  \
# 0    [1024, 1025, 1030, 1031, 1277, 1278, 1468, 172...        1 high
# 1    [23589, 23590, 23660, 23661, 23662, 23724, 237...        1 high
# 2    [15244, 15245, 15246, 15370, 15371, 15372, 153...        1 high
# 3    [18605, 18606, 18710, 18711, 18712, 18811, 188...        1 high
# 4    [5765, 5767, 5988, 6207, 6208, 6209, 6210, 642...        1 high
# ..                                                 ...           ...
# 468                                                NaN             0
# 469                                                NaN             0
# 470                                                NaN             0
# 471                                                NaN             0
# 472                                                NaN             0
#
#          tr_600    pop_tr_600  ...  \
# 0     50087.526  5.747078e+05  ...
# 1      8916.996  2.044677e+05  ...
# 2    222094.748  1.009671e+07  ...
# 3      9003.715  4.180547e+05  ...
# 4     12351.783  2.184325e+05  ...
# ..          ...           ...  ...
# 468         NaN           NaN  ...
# 469         NaN           NaN  ...
# 470         NaN           NaN  ...
# 471         NaN           NaN  ...
# 472         NaN           NaN  ...
#
#                                      tr_600Grid:Pentry  tr_600_access  \
# 0    [1024, 1025, 1026, 1027, 1028, 1029, 1030, 103...         1 high
# 1    [23450, 23451, 23516, 23517, 23518, 23519, 235...         1 high
# 2    [14822, 14823, 14824, 14972, 14973, 14974, 149...         1 high
# 3    [18439, 18440, 18441, 18443, 18604, 18605, 186...         1 high
# 4    [5323, 5324, 5326, 5551, 5552, 5553, 5554, 576...         1 high
# ..                                                 ...            ...
# 468                                                NaN              0
# 469                                                NaN              0
# 470                                                NaN              0
# 471                                                NaN              0
# 472                                                NaN              0
#
#         tr_1000   pop_tr_1000 popreachtr_1000 walkha_person_tr_1000  \
# 0    155153.171  2.026277e+06          5145.0              0.707083
# 1     38785.030  1.039931e+06          3079.0              8.055026
# 2    631963.265  3.124307e+07         65777.0              2.462364
# 3     43659.881  1.851339e+06          5372.0             87.914943
# 4     57917.494  1.372363e+06          4785.0             26.964493
# ..          ...           ...             ...                   ...
# 468    1058.323  1.458021e+04            88.0             48.559103
# 469         NaN           NaN             NaN                   NaN
# 470      42.505  8.501000e+01             4.0              0.738196
# 471         NaN           NaN             NaN                   NaN
# 472         NaN           NaN             NaN                   NaN
#
#      tr_1000_parks                                       tr_1000route  \
# 0            354.0  (LINESTRING (-75.2415597 40.0520621, -75.24156...
# 1            100.0  (LINESTRING (-75.2449838 39.924179, -75.245054...
# 2           1233.0  (LINESTRING (-75.2530653 39.9887453, -75.25336...
# 3            127.0  (LINESTRING (-75.1532837 39.9673479, -75.15352...
# 4            166.0  (LINESTRING (-75.17339 40.040145, -75.172542 4...
# ..             ...                                                ...
# 468            5.0  (LINESTRING (-75.251806 39.9526043, -75.251866...
# 469            NaN                                                NaN
# 470            2.0  (LINESTRING (-75.251806 39.9526043, -75.251866...
# 471            NaN                                                NaN
# 472            NaN                                                NaN
#
#                                     tr_1000Grid:Pentry  tr_1000_access
# 0    [1024, 1025, 1026, 1027, 1028, 1029, 1030, 103...          1 high
# 1    [23147, 23148, 23228, 23229, 23230, 23306, 233...          1 high
# 2    [14461, 14462, 14672, 14673, 14674, 14675, 146...          1 high
# 3    [17987, 17989, 17990, 17991, 17992, 18103, 181...          1 high
# 4    [4583, 4585, 4813, 4816, 4817, 4818, 4819, 482...          1 high
# ..                                                 ...             ...
# 468  [19901, 20004, 20110, 20214, 20318]:[7271, 727...          1 high
# 469                                                NaN               0
# 470                        [19901, 20004]:[7283, 7283]           3 low
# 471                                                NaN               0
# 472                                                NaN               0
#
# [473 rows x 24 columns]

# %%
# Block 10 get the preferenced parks for each grid (lowest score) for all distance decay variants.
preference = list([])
for n in enumerate(cities): 
    print(n[1])
    l1 = list(['raw','grav2','grav3','grav5'])
    m1 = list(['entrance','gravity**(1/2)','gravity**(1/3)','gravity**(1/5)'])
    prefer = list([])
    for j in enumerate(l1):
        pref = list([])
        print(m1[j[0]])
        for k in thresholds:
            score = 'tr_'+ str(k)
            g = gridpark[n[0]][j[0]].iloc[gridpark[n[0]][j[0]].groupby('Grid_No')[score].idxmax().dropna().astype(int)]
            g = g[g[score] > 0]
            g.join(grids[n[0]]['dissolve_key'], how = 'outer')
            g_csv = g.loc[:, (g.columns!='geometry_x') & (g.columns!='geometry_y')]
            
            if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_csv/'):
                os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_csv/')
                
            g_csv.to_csv('D:/Dumps/Scores output WPL-OSM/'+str(grid_block_size)
                         +'m grids/Grid_pref_parks_csv/park-pref_' + j[1] +'-'+ str(k) + '-' + n[1] +'.csv')
            
            g_lines = gpd.GeoDataFrame(g.loc[:, ~g.columns.isin(['geometry_y','geometry_m','Grid_m_centroid'])], geometry = 'geometry_x', crs = 4326)
            
            if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_lines/'):
                os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_lines/')
                
            g_lines.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)
                            +'m grids/Grid_pref_parks_lines/park-pref_' +'-'+ j[1] + str(k) + '-' + n[1] +'.shp')
            g_geoms = gpd.GeoDataFrame(g.loc[:, ~g.columns.isin(['geometry_x','geometry_m','Grid_m_centroid'])], geometry = 'geometry_y', crs = 4326)
            
            if not os.path.exists('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_geoms/'):
                os.makedirs('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)+'m grids/Grid_pref_parks_geoms/')
                
            g_geoms.to_file('D:Dumps/Scores output WPL-OSM/'+str(grid_block_size)
                            +'m grids/Grid_pref_parks_geoms/park-pref_' +'-'+ j[1] + str(k) + '-' + n[1] +'.shp')
            pref.append(g)
            print('park_prefer',k)
        prefer.append(pref)
        len(pref)
    preference.append(prefer)
print('all done')
preference[0][0][0]
# Out:
# Philadelphia
# entrance
# park_prefer 300
# park_prefer 600
# park_prefer 1000
# gravity**(1/2)
# park_prefer 300
# park_prefer 600
# park_prefer 1000
# gravity**(1/3)
# park_prefer 300
# park_prefer 600
# park_prefer 1000
# gravity**(1/5)
# park_prefer 300
# park_prefer 600
# park_prefer 1000
# all done
#          level_0      index  \
# 89440    57606.0    57606.0
# 89676    48328.0    48328.0
# 89966    48156.0    48156.0
# 90222    35417.0    35417.0
# 90553    35504.0    35504.0
# ...          ...        ...
# 85481  1566642.0  1567879.0
# 85486    32791.0    32791.0
# 85488  1566694.0  1567931.0
# 85490  1566695.0  1567932.0
# 85492  1566472.0  1567709.0
#
#                                               geometry_x  G1-P0     real_grid  \
# 89440  MULTILINESTRING ((-75.18732 40.05549, -75.1874...    1.0  1.099931e+08
# 89676  MULTILINESTRING ((-75.18696 40.05482, -75.1873...    1.0  1.099931e+08
# 89966  MULTILINESTRING ((-75.18605 40.05520, -75.1856...    1.0  5.542790e+09
# 90222  MULTILINESTRING ((-75.18506 40.05530, -75.1856...    1.0  1.098201e+08
# 90553  MULTILINESTRING ((-75.18446 40.05493, -75.1840...    1.0  1.103263e+08
# ...                                                  ...    ...           ...
# 85481  MULTILINESTRING ((-75.20587 40.05561, -75.2054...    1.0  1.098539e+08
# 85486  LINESTRING (-75.20540 40.05526, -75.20532 40.0...    1.0  8.038994e+09
# 85488                                               None    1.0  3.021105e+09
# 85490                                               None    1.0  3.021105e+09
# 85492  LINESTRING (-75.20256 40.05585, -75.20269 40.0...    1.0  3.021105e+09
#
#           real_park   way_calc.  route_cost  steps  Grid_No  ...   tr_600  \
# 89440  1.098076e+08  normal way     169.102    2.0       50  ...  345.438
# 89676  1.098076e+08  normal way     249.619    3.0       51  ...  302.210
# 89966  5.542790e+09  normal way     247.760    5.0       52  ...  308.680
# 90222  5.542790e+09  normal way     246.156    5.0       53  ...  303.794
# 90553  1.097644e+08  normal way     227.707    2.0       54  ...  332.101
# ...             ...         ...         ...    ...      ...  ...      ...
# 85481  5.284855e+09  normal way     242.938    2.0    34879  ...  320.048
# 85486  5.284855e+09  normal way     186.579    1.0    34880  ...  303.686
# 85488  3.021105e+09  normal way       0.000    0.0    34881  ...  487.108
# 85490  3.021105e+09  normal way       0.000    0.0    34882  ...  566.787
# 85492  3.021105e+09  normal way      68.042    1.0    34883  ...  523.085
#
#        poptr_600  adj_tr_600  walk_area_ha600 walkha_person600  tr_1000  \
# 89440  13472.082     345.438         4.863697         8.018591  745.438
# 89676  12088.400     302.210         4.863697         8.224196  702.210
# 89966  29015.920     308.680         4.863697        19.326861  708.680
# 90222  20050.404     303.794         4.863697        13.569924  703.794
# 90553  11955.636     332.101         4.342151         8.290821  732.101
# ...          ...         ...              ...              ...      ...
# 85481    640.096     320.048        24.092847         0.083012  720.048
# 85486    607.372     303.686        24.092847         0.083012  703.686
# 85488    974.216     487.108        28.816132         0.069406  887.108
# 85490   1133.574     566.787        28.816132         0.069406  966.787
# 85492    523.085     523.085        28.816132         0.034703  923.085
#
#        poptr_1000  adj_tr_1000  walk_area_ha1000  walkha_person1000
# 89440   29072.082     447.2628          4.863697           8.018591
# 89676   28088.400     421.3260          4.863697           8.224196
# 89966   66615.920     425.2080          4.863697          19.326861
# 90222   46450.404     422.2764          4.863697          13.569924
# 90553   26355.636     439.2606          4.342151           8.290821
# ...           ...          ...               ...                ...
# 85481    1440.096     432.0288         24.092847           0.083012
# 85486    1407.372     422.2116         24.092847           0.083012
# 85488    1774.216     532.2648         28.816132           0.069406
# 85490    1933.574     580.0722         28.816132           0.069406
# 85492     923.085     553.8510         28.816132           0.034703
#
# [11683 rows x 41 columns]

# %%
print(round((time.time() - start) / 60,2),'mns')
# Out:
# 174.81 mns
